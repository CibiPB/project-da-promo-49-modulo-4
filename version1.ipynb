# %%
import pandas as pd
import numpy as np

# %%
df_1 = pd.read_csv('All row files/1. US Police Shootings/shootings.csv',index_col=False)

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4895 entries, 0 to 4894
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       4895 non-null   int64
#  1   name                     4895 non-null   object
#  2   date                     4895 non-null   object
#  3   manner_of_death          4895 non-null   object
#  4   armed                    4895 non-null   object
#  5   age                      4895 non-null   float64
#  6   gender                   4895 non-null   object
#  7   race                     4895 non-null   object
#  8   city                     4895 non-null   object
#  9   state                    4895 non-null   object
#  10  signs_of_mental_illness  4895 non-null   bool
#  11  threat_level             4895 non-null   object
#  12  flee                     4895 non-null   object
#  13  body_camera              4895 non-null   bool
# ...

# %%
df_1['id'].duplicated().sum()
# Out:
# 0

# %%
df_1['manner_of_death'].unique()
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %%
df_1['armed'].unique()
# Out:
# array(['gun', 'unarmed', 'toy weapon', 'nail gun', 'knife', 'unknown',
#        'shovel', 'hammer', 'hatchet', 'sword', 'machete', 'box cutter',
#        'metal object', 'screwdriver', 'lawn mower blade', 'flagpole',
#        'guns and explosives', 'cordless drill', 'metal pole', 'Taser',
#        'metal pipe', 'metal hand tool', 'blunt object', 'metal stick',
#        'sharp object', 'meat cleaver', 'carjack', 'chain',
#        "contractor's level", 'stapler', 'crossbow', 'bean-bag gun',
#        'baseball bat and fireplace poker', 'straight edge razor',
#        'gun and knife', 'ax', 'brick', 'baseball bat', 'hand torch',
#        'chain saw', 'garden tool', 'scissors', 'pole', 'pick-axe',
#        'flashlight', 'vehicle', 'spear', 'chair', 'pitchfork',
#        'hatchet and gun', 'rock', 'piece of wood', 'bayonet', 'pipe',
#        'glass shard', 'motorcycle', 'pepper spray', 'metal rake', 'baton',
#        'crowbar', 'oar', 'machete and gun', 'air conditioner',
# ...

# %%
df_1['gender'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df_1['race'].unique()
# Out:
# array(['Asian', 'White', 'Hispanic', 'Black', 'Other', 'Native'],
#       dtype=object)

# %%
df_1['state'].unique()
# Out:
# array(['WA', 'OR', 'KS', 'CA', 'CO', 'OK', 'AZ', 'IA', 'PA', 'TX', 'OH',
#        'LA', 'MT', 'UT', 'AR', 'IL', 'NV', 'NM', 'MN', 'MO', 'VA', 'NJ',
#        'IN', 'KY', 'MA', 'NH', 'FL', 'ID', 'MD', 'NE', 'MI', 'GA', 'TN',
#        'NC', 'AK', 'NY', 'ME', 'AL', 'MS', 'WI', 'SC', 'DE', 'DC', 'WV',
#        'HI', 'WY', 'ND', 'CT', 'SD', 'VT', 'RI'], dtype=object)

# %%
df_1['arms_category'].unique()
# Out:
# array(['Guns', 'Unarmed', 'Other unusual objects', 'Piercing objects',
#        'Sharp objects', 'Unknown', 'Blunt instruments', 'Multiple',
#        'Electrical devices', 'Hand tools', 'Vehicles', 'Explosives'],
#       dtype=object)

# %%
df_2 = pd.read_csv('All row files/2. Wikipedia Serial Killers List/profile_killers.csv')

# %%
df_2.head()
# Out:
#                      Name                                          Nicknames  \
# 0           Luis Garavito  The Beast, Goofy, Conflict, Bonifacio Morera L...
# 1             Pedro López                           The Monster of the Andes
# 2             Javed Iqbal                                              Kukri
# 3          Mikhail Popkov  The Werewolf, The Angarsk Maniac, The Wednesda...
# 4  Daniel Camargo Barbosa  The Sadist of El Charquito, The Monster of the...
#
#     Age   Born Date                                  Born Location  \
# 0  66.0  1957-01-25                        Gnova, Quindo, Colombia
# 1   NaN  1948-10-08                            Venadillo, Colombia
# 2   NaN         NaN                       Lahore, Punjab, Pakistan
# 3   NaN  1964-03-07  Norilsk, Krasnoyarsk Krai, Russian SFSR, USSR
# 4  64.0  1930-01-22               Anolaima, Cundinamarca, Colombia
#
#     Died Date             Died Location  \
# 0  2023-10-12      Valledupar, Colombia
# ...

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 711 entries, 0 to 710
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              711 non-null    object
#  1   Nicknames         469 non-null    object
#  2   Age               243 non-null    float64
#  3   Born Date         444 non-null    object
#  4   Born Location     420 non-null    object
#  5   Died Date         308 non-null    object
#  6   Died Location     227 non-null    object
#  7   Conviction        502 non-null    object
#  8   Criminal Penalty  577 non-null    object
#  9   Date Apprehended  543 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 55.7+ KB

# %%
df_2['born country'] = df_2['Born Location'].apply(
    lambda x: x.split(',')[-1].strip() if pd.notnull(x) else None
)

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 711 entries, 0 to 710
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              711 non-null    object
#  1   Nicknames         469 non-null    object
#  2   Age               243 non-null    float64
#  3   Born Date         444 non-null    object
#  4   Born Location     420 non-null    object
#  5   Died Date         308 non-null    object
#  6   Died Location     227 non-null    object
#  7   Conviction        502 non-null    object
#  8   Criminal Penalty  577 non-null    object
#  9   Date Apprehended  543 non-null    object
#  10  born country      420 non-null    object
# dtypes: float64(1), object(10)
# memory usage: 61.2+ KB

# %%
pd.set_option('display.max_rows', None)

# %%
df_2['Born Location']
# Out:
# 0                                Gnova, Quindo, Colombia
# 1                                    Venadillo, Colombia
# 2                               Lahore, Punjab, Pakistan
# 3          Norilsk, Krasnoyarsk Krai, Russian SFSR, USSR
# 4                       Anolaima, Cundinamarca, Colombia
# 5             Santa Rita do Sapuca, Minas Gerais, Brazil
# 6                               Jaipur, Rajasthan, India
# 7                         Varamin, Tehran Province, Iran
# 8              Zhengyang County, Zhumadian, Henan, China
# 9                                 Abul DjabarAfghanistan
# 10                                                   NaN
# 11                                Protectorate of Uganda
# 12           e Heydarieh, Razavi Khorasan province, Iran
# 13            , Sumy Oblast, Ukrainian SSR, Soviet Union
# 14           Lasky, Zhytomyr Oblast, Ukrainian SSR, USSR
# 15                                         Uchoa, Brazil
# ...

# %%
df_2_a = (pd.read_csv('All row files/2. Wikipedia Serial Killers List/serial_killers_by_victims.csv'))

# %%
df_2_a.head(10)
# Out:
#                      Name                       Country  Start year  End year  \
# 0           Luis Garavito  Colombia, Ecuador, Venezuela      1992.0    1999.0
# 1             Pedro López       Colombia, Peru, Ecuador      1969.0    1980.0
# 2             Javed Iqbal                      Pakistan      1998.0    1999.0
# 3          Mikhail Popkov                        Russia      1992.0    2010.0
# 4  Daniel Camargo Barbosa     Colombia, Ecuador, Brazil      1974.0    1986.0
# 5   Pedro Rodrigues Filho                        Brazil      1967.0    2003.0
# 6   Kampatimar Shankariya                         India      1977.0    1978.0
# 7           Hoshang Amini                          Iran      1954.0    1962.0
# 8             Yang Xinhai                         China      1999.0    2003.0
# 9             Abul Djabar                   Afghanistan         NaN    1970.0
#
#    Proven victims  Possible victims  \
# 0           193.0             247.0
# ...

# %%
df_2_a["Country"].unique()
# Out:
# array(['Colombia, Ecuador, Venezuela', 'Colombia, Peru, Ecuador',
#        'Pakistan', 'Russia', 'Colombia, Ecuador, Brazil', 'Brazil',
#        'India', 'Iran', 'China', 'Afghanistan', 'United States',
#        'Belgian Congo, Tanganyika', 'Soviet Union',
#        'Soviet Union, Ukraine', 'Indonesia', 'South Africa', 'Morocco',
#        'Kingdom of Romania, Yugoslavia, Hungary', 'Mexico',
#        'Ottoman Empire, Iraq, Iran', 'Egypt', 'Germany', 'Colombia',
#        'Zambia', 'Swaziland', 'Greece', 'Canada', 'United Kingdom',
#        'Austria-Hungary', 'France, Germany, Switzerland', 'Ecuador',
#        'United States, Canada', 'Soviet Union, Russia, Tajikistan',
#        'Romania', 'South Korea', 'Costa Rica', 'Soviet Union, Russia',
#        'Latvia', 'Turkey', 'France', 'Sri Lanka', 'Peru', 'Ukraine',
#        'Italy', 'France, Belgium', 'Spain', 'United States, Mexico',
#        'Argentina', 'Poland', 'Chile', 'West Germany', 'Tunisia',
# ...

# %%
df_2_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 757 entries, 0 to 756
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              757 non-null    object
#  1   Country           757 non-null    object
#  2   Start year        738 non-null    float64
#  3   End year          740 non-null    float64
#  4   Proven victims    757 non-null    float64
#  5   Possible victims  757 non-null    float64
#  6   Notes             754 non-null    object
#  7   country sorted    757 non-null    object
#  8   Continent         756 non-null    object
# dtypes: float64(4), object(5)
# memory usage: 53.4+ KB

# %%
df_2["born country"].unique()
# Out:
# array(['Colombia', 'Pakistan', 'USSR', 'Brazil', 'India', 'Iran', 'China',
#        'Abul DjabarAfghanistan', None, 'Protectorate of Uganda',
#        'Soviet Union', 'Indonesia', 'South Africa', 'Byelorussian SSR',
#        'Morocco', 'Romania', 'Mexico', 'Russian Empire', 'Egypt',
#        'Greece', 'Maoupa Cedric MaakeSouth Africa', 'Canada', 'England',
#        'German Empire', 'Hungary', 'France', 'Ecuador', 'RSFSR',
#        'South Korea', 'Turkey', 'United States', 'Martinique', 'Peru',
#        'Ukrainian SSR', 'Italy', 'Imperial State of Iran', 'Spain',
#        'Elias XitavhudziUnion of South Africa', 'Uttar Pradesh',
#        'Argentina', 'Union of South Africa', 'Norway', 'Poland', 'Chile',
#        'Germany', 'French Tunisia', 'United States of Brazil',
#        'Venezuela', 'Tajik SSR', 'Latvia',
#        'Johannes MashianeSouth Africa', 'Georgian SSR',
#        'North German Confederation', 'Scotland', 'Yemen',
# ...

# %%
country_to_continent = {
    # Américas
    "Brazil": "South America",
    "Colombia": "South America",
    "Argentina": "South America",
    "Chile": "South America",
    "Ecuador": "South America",
    "Peru": "South America",
    "Mexico": "North America",
    "United States": "North America",
    "Canada": "North America",
    "Costa Rica": "Central America",
    "Guatemala": "Central America",
    "Belize": "Central America",
    "Panama": "Central America",
    # Europa
    "France": "Europe",
    "Germany": "Europe",
    "Spain": "Europe",
    "Italy": "Europe",
    "United Kingdom": "Europe",
    "Poland": "Europe",
    "Romania": "Europe",
    "Hungary": "Europe",
    "Ukraine": "Europe",
    "Russia": "Europe/Asia",  # pode ser refinado
    "Austria": "Europe",
    "Czech Republic": "Europe",
    "Netherlands": "Europe",
    "Switzerland": "Europe",
    "Belgium": "Europe",
    "Latvia": "Europe",
    "Greece": "Europe",
    "Serbia and Montenegro": "Europe",
    "Estonia": "Europe",
    "Republic of Macedonia": "Europe",
    # Ásia
    "China": "Asia",
    "India": "Asia",
    "Pakistan": "Asia",
    "Iran": "Asia",
    "Afghanistan": "Asia",
    "Indonesia": "Asia",
    "South Korea": "Asia",
    "North Korea": "Asia",
    "Japan": "Asia",
    "Bangladesh": "Asia",
    "Turkey": "Asia/Europe",
    "Kazakhstan": "Asia",
    "Tajikistan": "Asia",
    "Sri Lanka": "Asia",
    "Malaysia": "Asia",
    "Thailand": "Asia",
    "Nepal": "Asia",
    "Uzbekistan": "Asia",
    "Yemen": "Asia",
    "Israel": "Asia",
    # África
    "South Africa": "Africa",
    "Egypt": "Africa",
    "Morocco": "Africa",
    "Zambia": "Africa",
    "Swaziland": "Africa",
    "Rwanda": "Africa",
    "Namibia": "Africa",
    "Portuguese Angola": "Africa",
    "Tanganyika": "Africa",
    "Belgian Congo": "Africa",
    "Kenya": "Africa",
    # Oceania
    "Australia": "Oceania",
    "New Zealand": "Oceania",
    # Outros
    "Soviet Union": "Former USSR",
    "Ottoman Empire": "Historical",
    "Austria-Hungary": "Historical",
    "Czechoslovakia": "Historical",
    "West Germany": "Historical",
    "East Germany": "Historical",
    "SR Croatia": "Historical",
    "SR Slovenia": "Historical",
    "Kingdom of Romania": "Historical",
    "Kingdom of Yugoslavia": "Historical",
}

# %%
# Exemplo com lista
countries = ['Colombia, Ecuador, Venezuela', 'Pakistan', 'Russia']
df = pd.DataFrame({'countries': countries})
# Aplica categorização
df['continents'], not_matched = categorize_by_continent(df['countries'], country_to_continent)
print(df)
print("Not matched countries:", not_matched)

# %%
def categorize_multiple_countries(country_series):
    return country_series.apply(lambda x: "Multiple Countries" if ',' in x else x)

# %%
df_2_country_sorted = pd.DataFrame({'Country': df_2_a["Country"]})

# Aplica a função
df_2_a['country sorted'] = categorize_multiple_countries(df_2_a['Country'])

display(df_2_a)
# Out:
#                                      Name                       Country  \
# 0                           Luis Garavito  Colombia, Ecuador, Venezuela
# 1                             Pedro López       Colombia, Peru, Ecuador
# 2                             Javed Iqbal                      Pakistan
# 3                          Mikhail Popkov                        Russia
# 4                  Daniel Camargo Barbosa     Colombia, Ecuador, Brazil
# ..                                    ...                           ...
# 752  Michael Bear Carson and Suzan Carson                 United States
# 753          Joseph and Michael Kallinger                 United States
# 754                     Silvia Merez Cult                        Mexico
# 755    Raya and Sakina and their husbands                         Egypt
# 756         Amelia Sach and Annie Walters                United Kingdom
#
#      Start year  End year  Proven victims  Possible victims  \
# ...

# %%
df_2_a[df_2_a["country sorted"]=="Multiple Countries"].shape[0]
# Out:
# 44

# %%
continent_dict = {
    'Multiple Countries': 'Multiple',
    'Pakistan': 'Asia',
    'Russia': 'Europe/Asia',
    'Brazil': 'South America',
    'India': 'Asia',
    'Iran': 'Asia',
    'China': 'Asia',
    'Afghanistan': 'Asia',
    'United States': 'North America',
    'Soviet Union': 'Europe/Asia',
    'Indonesia': 'Asia',
    'South Africa': 'Africa',
    'Morocco': 'Africa',
    'Mexico': 'North America',
    'Egypt': 'Africa',
    'Germany': 'Europe',
    'Colombia': 'South America',
    'Zambia': 'Africa',
    'Swaziland': 'Africa',
    'Greece': 'Europe',
    'Canada': 'North America',
    'United Kingdom': 'Europe',
    'Austria-Hungary': 'Europe',
    'Ecuador': 'South America',
    'Romania': 'Europe',
    'South Korea': 'Asia',
    'Costa Rica': 'North America',
    'Latvia': 'Europe',
    'Turkey': 'Europe/Asia',
    'France': 'Europe',
    'Sri Lanka': 'Asia',
    'Peru': 'South America',
    'Ukraine': 'Europe',
    'Italy': 'Europe',
    'Spain': 'Europe',
    'Argentina': 'South America',
    'Poland': 'Europe',
    'Chile': 'South America',
    'West Germany': 'Europe',
    'Tunisia': 'Africa',
    'Venezuela': 'South America',
    'Rwanda': 'Africa',
    'Yemen': 'Asia',
    'Japan': 'Asia',
    'Belgium': 'Europe',
    'Bangladesh': 'Asia',
    'Czechoslovakia': 'Europe',
    'Kenya': 'Africa',
    'Denmark': 'Europe',
    'Sweden': 'Europe',
    'Australia': 'Oceania',
    'Cyprus': 'Asia',
    'Belarus': 'Europe',
    'Estonia': 'Europe',
    'Netherlands': 'Europe',
    'SR Croatia': 'Europe',
    'Panama': 'North America',
    'Singapore': 'Asia',
    'Belize': 'North America',
    'SR Slovenia': 'Europe',
    'Namibia': 'Africa',
    'Austria': 'Europe',
    'Hong Kong': 'Asia',
    'Israel': 'Asia',
    'Republic of Macedonia': 'Europe',
    'East Germany': 'Europe',
    'Portugal': 'Europe',
    'Malaysia': 'Asia',
    'Kingdom of Yugoslavia': 'Europe',
    'Iraq': 'Asia',
    'Norway': 'Europe',
    'Switzerland': 'Europe',
    'Czech Republic': 'Europe',
    'Imperial State of Iran': 'Asia',
    'Finland': 'Europe',
    'Hungary': 'Europe',
    'Guatemala': 'North America'
}


df_2_a['Continent'] = df_2_a['country sorted'].map(continent_dict)

# %%
df_2_a.head()
# Out:
#                      Name                       Country  Start year  End year  \
# 0           Luis Garavito  Colombia, Ecuador, Venezuela        1992      1999
# 1             Pedro López       Colombia, Peru, Ecuador        1969      1980
# 2             Javed Iqbal                      Pakistan        1998      1999
# 3          Mikhail Popkov                        Russia        1992      2010
# 4  Daniel Camargo Barbosa     Colombia, Ecuador, Brazil        1974      1986
#
#    Proven victims  Possible victims  \
# 0             193               247
# 1             110               300
# 2             100               100
# 3              83                86
# 4              72               180
#
#                                                Notes      country sorted  \
# 0  Child-murderer, torture-killer, and rapist kno...  Multiple Countries
# 1  Child-murderer and rapist, known as "The Monst...  Multiple Countries
# ...

# %%
df_2_a["Continent"].unique()
# Out:
# array(['Multiple', 'Asia', 'Europe/Asia', 'South America',
#        'North America', 'Africa', 'Europe', 'Oceania'], dtype=object)

# %%
df_2_a.to_csv("All row files/2. Wikipedia Serial Killers List/serial_killers_by_victims.csv", index=False)

# %%
columnas=["Start year","End year", "Proven victims","Possible victims"]

# %%
for col in columnas:
    df_2_a[col] = df_2_a[col].round().astype('Int64')

# %%
df_2_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 757 entries, 0 to 756
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              757 non-null    object
#  1   Country           757 non-null    object
#  2   Start year        738 non-null    Int64
#  3   End year          740 non-null    Int64
#  4   Proven victims    757 non-null    Int64
#  5   Possible victims  757 non-null    Int64
#  6   Notes             754 non-null    object
#  7   country sorted    757 non-null    object
#  8   Continent         757 non-null    object
# dtypes: Int64(4), object(5)
# memory usage: 56.3+ KB

# %%
df_killers_byvictims = (pd.read_csv('All row files/2. Wikipedia Serial Killers List/V1-serial_killers_by_victims.csv'))

# %%
df_killers_byvictims.head()
# Out:
#                      Name                       Country  Start year  End year  \
# 0           Luis Garavito  Colombia, Ecuador, Venezuela      1992.0    1999.0
# 1             Pedro López       Colombia, Peru, Ecuador      1969.0    1980.0
# 2             Javed Iqbal                      Pakistan      1998.0    1999.0
# 3          Mikhail Popkov                        Russia      1992.0    2010.0
# 4  Daniel Camargo Barbosa     Colombia, Ecuador, Brazil      1974.0    1986.0
#
#    Proven victims  Possible victims  \
# 0             193               247
# 1             110               300
# 2             100               100
# 3              83                86
# 4              72               180
#
#                                                Notes      Continent  \
# 0  Child-murderer, torture-killer, and rapist kno...  South America
# 1  Child-murderer and rapist, known as "The Monst...  South America
# ...

# %%
columnas=["Start year","End year","Years Active"]

# %%
for col in columnas:
 df_killers_byvictims[col] = df_killers_byvictims[col].round().astype('Int64')

# %%
df_killers_byvictims.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 757 entries, 0 to 756
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              757 non-null    object
#  1   Country           757 non-null    object
#  2   Start year        738 non-null    Int64
#  3   End year          740 non-null    Int64
#  4   Proven victims    757 non-null    int64
#  5   Possible victims  757 non-null    int64
#  6   Notes             754 non-null    object
#  7   Continent         757 non-null    object
#  8   Country Sorted    757 non-null    object
#  9   Years Active      723 non-null    Int64
#  10  Decade            757 non-null    object
#  11  Crime Type        757 non-null    object
#  12  GroupType         757 non-null    object
#  13  Killer Type       757 non-null    object
# dtypes: Int64(3), int64(2), object(9)
# memory usage: 85.1+ KB

# %% [markdown]
# ### 🔪Crear Top 10 de Serial Killers mundiales con columna de imagenes

# %%
# Ordenar por víctimas confirmadas y quedarnos con los 10 primeros
top10 = df_killers_byvictims.sort_values(by='Proven victims', ascending=False,).head(10).copy()
top10
# Out:
#                                     Name                       Country  \
# 675                  Murder Incorporated                 United States
# 623                       Harold Shipman                United Kingdom
# 0                          Luis Garavito  Colombia, Ecuador, Venezuela
# 676             Philadelphia poison ring                 United States
# 1                            Pedro López       Colombia, Peru, Ecuador
# 677                   Abboud and Khajawa                          Iraq
# 624                        Steven Massof                 United States
# 2                            Javed Iqbal                      Pakistan
# 678  Delfina and María de Jesús González                        Mexico
# 625                          Niels Högel                       Germany
#
#      Start year  End year  Proven victims  Possible victims  \
# 675        1920      <NA>             400              1000
# 623        1975      1998             218               250
# ...

# %%
top10["Name"]# Tenemos un problema con Steven Massof, era un trabajador de la clínica que testificó y fué declarado culpable 
            #  pero la mente criminal y la clínica de abortos pertenecía a Kermit Gosnell.
# Out:
# 675                    Murder Incorporated
# 623                         Harold Shipman
# 0                            Luis Garavito
# 676               Philadelphia poison ring
# 1                              Pedro López
# 677                     Abboud and Khajawa
# 624                          Steven Massof
# 2                              Javed Iqbal
# 678    Delfina and María de Jesús González
# 625                            Niels Högel
# Name: Name, dtype: object

# %%
imagenes = {
    'Murder Incorporated': 'https://www.legendsofamerica.com/wp-content/uploads/2017/08/Murderinc.jpg',
    'Harold Shipman': 'https://m.media-amazon.com/images/S/pv-target-images/43d413170f9c3edaac3eceefaedc067b210f7cd44f5566140bceeb13ac977637.jpg',
    'Luis Garavito': 'https://upload.wikimedia.org/wikipedia/commons/7/7b/Luis_Alfredo_Garavito_Cubillos.jpg',
    'Philadelphia poison ring': 'https://cvltnation.com/wp-content/uploads/2024/05/237242122_569851784394295_854447.jpg',
    'Pedro López': 'https://s3.amazonaws.com/arc-wordpress-client-uploads/infobae-wp/wp-content/uploads/2018/11/14100939/Pedro-Alonso-Lopez-el-Monstruo-de-los-Andes-3.jpg',
    'Abboud and Khajawa': 'https://upload.wikimedia.org/wikipedia/en/d/da/AbboudandKhajawa.png',
    'Steven Massof': 'https://media.philly.com/images/20140213_dn_0n0wr3al.jpg',
    'Javed Iqbal': 'https://image.geo.de/30117460/t/8P/v4/w1440/r0/-/javed-iqbal-ap-0001270313-sw-jpg--65811-.jpg',
    'Delfina and María de Jesús González': 'https://upload.wikimedia.org/wikipedia/commons/c/ca/Las_Pochianquis.jpg',
    'Niels Högel': 'https://www.lavanguardia.com/files/content_image_mobile_filter/uploads/2022/04/21/6261a4bb37515.jpeg'
}

# %%
top10['Image'] = top10['Name'].map(imagenes)

# %% [markdown]
# ### 🕵️‍♂️Crear columna con años de actuvidad

# %%
# Aseguramos que Start year y End year son números
df_killers_byvictims['Start year'] = pd.to_numeric(df_killers_byvictims['Start year'], errors='coerce')
df_killers_byvictims['End year'] = pd.to_numeric(df_killers_byvictims['End year'], errors='coerce')



# Creamos Years Active, dejando NaN si falta Start year
df_killers_byvictims['Years Active'] = df_killers_byvictims['End year'] - df_killers_byvictims['Start year']

# %%
df_killers_byvictims.head()
# Out:
#                      Name                       Country  Start year  End year  \
# 0           Luis Garavito  Colombia, Ecuador, Venezuela        1992      1999
# 1             Pedro López       Colombia, Peru, Ecuador        1969      1980
# 2             Javed Iqbal                      Pakistan        1998      1999
# 3          Mikhail Popkov                        Russia        1992      2010
# 4  Daniel Camargo Barbosa     Colombia, Ecuador, Brazil        1974      1986
#
#    Proven victims  Possible victims  \
# 0             193               247
# 1             110               300
# 2             100               100
# 3              83                86
# 4              72               180
#
#                                                Notes      Continent  \
# 0  Child-murderer, torture-killer, and rapist kno...  South America
# 1  Child-murderer and rapist, known as "The Monst...  South America
# ...

# %%
df_killers_byvictims["Years Active"].isna().sum() #nos encontramos con 34 nulos
# Out:
# 34

# %%
# Asegurar que Start year es número
df_killers_byvictims['Start year'] = pd.to_numeric(df_killers_byvictims['Start year'], errors='coerce')

# Crear la columna Decade
df_killers_byvictims['Decade'] = (df_killers_byvictims['Start year'] // 10) * 10

# %%
df_killers_byvictims['Decade'] = df_killers_byvictims['Decade'].astype('Int64').astype(str) + 's'

# %%
df_killers_byvictims.head()
# Out:
#                      Name                       Country  Start year  End year  \
# 0           Luis Garavito  Colombia, Ecuador, Venezuela        1992      1999
# 1             Pedro López       Colombia, Peru, Ecuador        1969      1980
# 2             Javed Iqbal                      Pakistan        1998      1999
# 3          Mikhail Popkov                        Russia        1992      2010
# 4  Daniel Camargo Barbosa     Colombia, Ecuador, Brazil        1974      1986
#
#    Proven victims  Possible victims  \
# 0             193               247
# 1             110               300
# 2             100               100
# 3              83                86
# 4              72               180
#
#                                                Notes      Continent  \
# 0  Child-murderer, torture-killer, and rapist kno...  South America
# 1  Child-murderer and rapist, known as "The Monst...  South America
# ...

# %%
crime_keywords = {
    'Murder': ['murder', 'kill', 'killing', 'homicide'],
    'Kidnapping': ['kidnap', 'abduction'],
    'Rape': ['rape', 'sexual assault', 'molestation'],
    'Torture': ['torture', 'mutilation', 'disembowelment'],
    'Robbery': ['robbery', 'theft', 'steal'],
    'Poisoning': ['poison', 'toxins', 'overdose'],
    'Arson': ['arson', 'fire', 'burn'],
    'Necrophilia': ['necrophilia', 'corpse abuse'],
    'Cannibalism': ['cannibalism', 'eating', 'consumed'],
    'Angel of Mercy': ['angel of mercy', 'angel of death', 'caregiver', 'nurse'],
    'Pedophilia': ['pedophilia', 'child abuse', 'child molestation', 'child rape', 'sexual assault on children', 'sexual exploitation of children']
}

# %%
# Diccionario actualizado con pedofilia
crime_keywords = {
    'Pedophilia': ['Child-murderer','pedophilia', 'child abuse', 'child molestation', 'child rape', 'sexual assault on children', 'sexual exploitation of children'],
    'Kidnapping': ['kidnap', 'abduction'],
    'Rape': ['rape', 'sexual assault', 'molestation'],
    'Torture': ['torture', 'mutilation', 'disembowelment'],
    'Robbery': ['robbery', 'theft', 'steal'],
    'Poisoning': ['poison', 'toxins', 'overdose'],
    'Arson': ['arson', 'fire', 'burn'],
    'Necrophilia': ['necrophilia', 'corpse abuse'],
    'Cannibalism': ['cannibalism', 'eating', 'consumed'],
    'Angel of Mercy': ['angel of mercy', 'angel of death', 'caregiver', 'nurse'],}
    

# Función para asignar el tipo de crimen (con protección contra valores no string)
def categorize_crime(notes, crime_keywords):
    if isinstance(notes, str):  # Verificamos si 'notes' es una cadena de texto
        for crime, keywords in crime_keywords.items():
            if any(keyword in notes.lower() for keyword in keywords):
                return crime
    return 'Other'  # Si no se encuentra una coincidencia o el valor no es un string

# Aplicar la función al DataFrame
df_killers_byvictims['Crime Type'] = df_killers_byvictims['Notes'].apply(categorize_crime, crime_keywords=crime_keywords)

# Mostrar el resultado
print(df_killers_byvictims[['Name', 'Notes', 'Crime Type']])
# Out:
#                                                   Name  \
# 0                                        Luis Garavito
# 1                                          Pedro López
# 2                                          Javed Iqbal
# 3                                       Mikhail Popkov
# 4                               Daniel Camargo Barbosa
# 5                                Pedro Rodrigues Filho
# 6                                Kampatimar Shankariya
# 7                                        Hoshang Amini
# 8                                          Yang Xinhai
# 9                                          Abul Djabar
# 10                                       Samuel Little
# 11                                        William Unek
# 12                                      Mohammed Bijeh
# 13                                    Andrei Chikatilo
# 14                                  Anatoly Onoprienko
# 15                             Florisvaldo de Oliveira
# ...

# %%
crime_keywords = {

    'Pedophilia': ['Child','child-murderer','pedophilia', 'child abuse', 'child molestation', 'child rape', 'sexual assault on children', 'sexual exploitation of children'],
    'Kidnapping': ['kidnap', 'abduction'],
    'Rape': ['rape','rapist-killer', 'sexual assault', 'molestation'],
    'Torture': ['torture', 'mutilation', 'disembowelment'],
    'Robbery': ['robbery', 'theft', 'steal'],
    'Poisoning': ['poison', 'toxins', 'overdose'],
    'Arson': ['arson', 'fire', 'burn'],
    'Necrophilia': ['necrophilia', 'corpse abuse'],
    'Cannibalism': ['canibalized','cannibalism', 'eating', 'consumed'],
    'Angel of Mercy': ['angel of mercy', 'angel of death', 'caregiver', 'nurse'],
    'Murder':["killing"]
}
def categorize_crime(notes, crime_keywords):
    if isinstance(notes, str):  # Verificar si 'notes' es un string
        for crime, keywords in crime_keywords.items():
            if any(keyword in notes.lower() for keyword in keywords):  # Convertir a minúsculas
                return crime
    return 'Other'

# Aplicar la función al DataFrame
df_killers_byvictims['Crime Type'] = df_killers_byvictims['Notes'].apply(categorize_crime, crime_keywords=crime_keywords)

# %%
df_killers_byvictims["Crime Type"].value_counts()
# Out:
# Crime Type
# Other             477
# Rape               78
# Murder             64
# Poisoning          47
# Kidnapping         27
# Angel of Mercy     22
# Torture            11
# Arson              10
# Robbery             8
# Necrophilia         6
# Cannibalism         4
# Pedophilia          3
# Name: count, dtype: int64

# %% [markdown]
# ### Crear columna por Género 🚻

# %%
# Listas de clasificación

female_killers = [
    'Marie Fikáčková', 'Ivanova and Olga Tamarin', 'Gwendolyn Graham and Catherine May Wood',
    'Felícitas Sánchez Aguillón', 'Delfina and María de Jesús González', 'Angel Makers of Nagyrév',
    'Lainz Angels of Death', 'Silvia Merez Cult', 'Amelia Sach and Annie Walters', 'Belle Gunness',
    'Aileen Wuornos', 'Dorothea Puente', 'Juana Barraza', 'Jane Toppan', 'Genene Jones',
    'Beverley Allitt', 'Enriqueta Martí', 'Tillie Klimek', 'Mariane Nölle', 'Vickie Dawn Jackson',
    'Joan Vila', 'Linda Hazzard', 'Ann Arber Hospital Killer', 'Elizabeth Wettlaufer', 'Velma Barfield',
    'Lyda Southard', 'Shirley Winters', 'Francisca Ballesteros', 'Valery Asratyan', 'Martha Rendell',
    'Sharon Kinne', 'Leonarda Cianciulli', 'Bertha Gifford', 'Rhonda Belle Martin', 'Reta Mays',
    'Marybeth Tinning', 'Jeanne Weber', 'Marie Alexandrine Becker', 'Antoinette Scieri', 'Kristen Gilbert',
    'Sonya Caleffi', 'Kimberly Clark Saenz', 'Vera Renczi', 'Mariam Soulakiotis', 'Irina Gaidamachuk',
    'Tamara Samsonova', 'Celine Lesage', 'Elisabeth Wiese', 'Anna Marie Hahn', 'Waneta Hoyt',
    'Lucy Letby', 'Frans Hooijmaijers', 'Miyuki Ishikawa', 'Amy Archer-Gilligan', 'Aino Nykopp-Koski',
    'Elfriede Blauensteiner', 'Joanna Dennehy', 'Mary Elizabeth Wilson'
]

gangs = [
    "Raya and Sakina and their husbands", "Beasts of Satan", "Chijon Family", "The Family",
    "Ian Brady and Myra Hindley", "Ray and Faye Copeland", "The Skin Hunters", "The Hernández Brothers Sect",
    "The Ciudad Juárez Rebels", "Tadeusz Grzesik and the Bureaucrats Gang", "The Manson Family cult killings",
    "National Socialist Underground", "Joshi-Abhyankar serial murderers", "Hillside Stranglers",
    "Bloody Benders", "The Cleaners", "Lainz Angels of Death", "Death Angels", "Ripper Crew",
    "Anísio Ferreira de Sousa and followers", "Marcelo de Jesus Silva and his death squad", "Shankill Butchers",
    "Brabant killers", "Gang of Amazons", "Murder Incorporated", "Auto Shankar's Gang", "Mailoni Brothers",
    "Briley Brothers", "David Avendaño Ballina and his followers", "Philadelphia poison ring"
]

couples = [
    "Michael Bear Carson and Suzan Carson", "Paul Bernardo and Karla Homolka", "Raymond Fernandez and Martha Beck",
    "David and Catherine Birnie", "James Gregory Marlow and Cynthia Coffman", "Rudolfo Infante and Anna Villeda",
    "Gerald and Charlene Gallego", "Juan Carlos Hernández and Patricia Martínez", "Fred West and Rosemary West",
    "Adolfo Constanzo and Sara Aldrete", "Ray and Faye Copeland", "Ian Brady and Myra Hindley",
    "Futoshi Matsunaga and Junko Ogata", "Long Zhimin and Yan Shuxia", "Abboud and Khajawa"
]

male_groups = [
    "Joseph and Michael Kallinger", "James Paster and Stephen McCoy", "John Duffy and David Mulcahy",
    "Loren Herzog and Wesley Shermantine", "Lawrence Bittaker and Roy Norris",
    "Artyom Alexandrovich Anoufriev and Nikita Vakhtangovich Lytkin", "David Alan Gore and Fred Waterfield",
    "Hermann Duft and Hans Wilhelm Bassenauer", "Kiss brothers and Zsolt István Pető", "Gert van Rooyen and Joey Haarhof",
    "Johannes van Rooyen and Dumisani Makhubela", "Fa Ziying and Lao Rongzhi", "Christopher Worrell and James Miller",
    "Dale Hausner and Samuel Dieteman", "Edgar Álvarez Cruz and Francisco Granados", "Song Jinghua and Yan Jinguang",
    "Yevgeny Nagorny and Sergei Stavitsky", "Wolfgang Abel and Marco Furlan", "Polatbay Berdaliyev and Abduseit Ormanov",
    "Shen Changyin and Shen Changpin", "Leonard Lake and Charles Ng", "John Justin Bunting, Robert Joe Wagner and James Spyridon Vlassakis",
    "José Miculax Bux and Mariano Macú Miculax", "Vladyslav Volkovic and Volodymyr Kondratenko",
    "John Allen Muhammad and Lee Boyd Malvo", "Wang Zongfang and Wang Zongwei", "Viktor Sayenko and Igor Suprunyuk",
    "Dean Corll, David Owen Brooks and Elmer Wayne Henley", "Bian Kuang, Fu Xinyuan and Luo Lianshun",
    "Hassan Orangi and Abbas Ali Zarifian", "Peng Miaoji, Ding Yunjia and Su Xiaoping"
]

unidentified = [
    "Monster of the Mangones", "Cape Town Prostitute Killer", "El Psicópata",
    "Atlanta Ripper", "Cleveland Torso Murderer", "Rainbow Maniac", "Paraquat murders",
    "Long Island serial killer", "New Bedford Highway", "Edgecombe County Serial Killer",
    "Axeman of New Orleans", "Forest City Killer", "Łódź Gay Murderer", "The Doodler", "Bible John","Monster of Florence"
]
def classify_killer(name):
    if name in female_killers:
        return 'Female'
    elif name in gangs:
        return 'Gang'
    elif name in couples:
        return 'Couple'
    elif name in male_groups:
        return 'Male Group'
    elif name in unidentified:
        return 'Unidentified'
    else:
        return 'Male'

# Aplicamos al DataFrame
df_killers_byvictims['Killer Type'] = df_killers_byvictims['Name'].apply(classify_killer)

# %% [markdown]
# ### Guardar en archivo csv el Top 10 de asesinos en serie 📂

# %%
# Guardar el DataFrame del top 10 de asesinosen serie en un archivo CSV
top10.to_csv('top10_serial_killers_by victims.csv', index=False)

# %%
top10
# Out:
#                                     Name                       Country  \
# 675                  Murder Incorporated                 United States
# 623                       Harold Shipman                United Kingdom
# 0                          Luis Garavito  Colombia, Ecuador, Venezuela
# 676             Philadelphia poison ring                 United States
# 1                            Pedro López       Colombia, Peru, Ecuador
# 677                   Abboud and Khajawa                          Iraq
# 624                        Steven Massof                 United States
# 2                            Javed Iqbal                      Pakistan
# 678  Delfina and María de Jesús González                        Mexico
# 625                          Niels Högel                       Germany
#
#      Start year  End year  Proven victims  Possible victims  \
# 675        1920      <NA>             400              1000
# 623        1975      1998             218               250
# ...
