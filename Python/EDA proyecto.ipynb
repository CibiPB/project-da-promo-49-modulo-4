# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### EDA PROFILE:

# %%
profile = pd.read_csv('../Clean Files/Profile/0V-profile_killers.csv')

# %%
#IDENTIFYING NULLS AND DATA TYPE

profile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 711 entries, 0 to 710
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              711 non-null    object
#  1   Nicknames         469 non-null    object
#  2   Age               243 non-null    float64
#  3   Born Date         444 non-null    object
#  4   Born Location     420 non-null    object
#  5   Died Date         308 non-null    object
#  6   Died Location     227 non-null    object
#  7   Conviction        502 non-null    object
#  8   Criminal Penalty  577 non-null    object
#  9   Date Apprehended  543 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 55.7+ KB

# %%
# SPLITING BORN LOCATION, TO CREATE NEW COLUMN WITH COUNTRY


profile['born country'] = profile['Born Location'].apply(
    lambda x: x.split(',')[-1].strip() if pd.notnull(x) else None)

# %%
# CAN IDENTIFY DATA AGE IS ACTUALY AGE THE PERSON DIED

#pd.set_option('display.max_rows', None)
profile[profile['Age'].notna()].head()
# Out:
#                       Name                                          Nicknames  \
# 0            Luis Garavito  The Beast, Goofy, Conflict, Bonifacio Morera L...
# 4   Daniel Camargo Barbosa  The Sadist of El Charquito, The Monster of the...
# 5    Pedro Rodrigues Filho                     Killer Petey, Pedrinho Matador
# 10           Samuel Little  Samuel Mc, Dowell, The Choke--Stroke Killer, M...
# 13        Andrei Chikatilo  The Butcher of Rostov, The Forest Strip Killer...
#
#      Age   Born Date                               Born Location   Died Date  \
# 0   66.0  1957-01-25                     Gnova, Quindo, Colombia  2023-10-12
# 4   64.0  1930-01-22            Anolaima, Cundinamarca, Colombia  1994-11-13
# 5   68.0  1954-10-29  Santa Rita do Sapuca, Minas Gerais, Brazil  2023-03-05
# 10  80.0  1940-06-07                                         NaN  2020-12-30
# 13  57.0  1936-10-16  , Sumy Oblast, Ukrainian SSR, Soviet Union  1994-02-14
#
#                            Died Location  \
# 0                   Valledupar, Colombia
# 4                     Guayaquil, Ecuador
# 5      Mogi das Cruzes, So Paulo, Brazil
# 10                                   NaN
# 13  Novocherkassk, Rostov Oblast, Russia
#
#                                            Conviction  \
# 0                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 10                                             Murder
# 13  Murder With Aggravating Circumstances, Seual A...
#
#                                      Criminal Penalty Date Apprehended  \
# 0                                                 NaN       1999-04-22
# 4        25 years imprisonment, 16 years imprisonment       1974-05-03
# 5   30 years imprisonment (1973 to 2007), 8 years ...              NaN
# 10  Four life sentence(s) without the possibility ...       2012-09-05
# 13                                              death       1990-11-20
#
#     born country
# 0       Colombia
# 4       Colombia
# 5         Brazil
# 10          None
# 13  Soviet Union

# %%
# ENSURING COLUMNS ARE IN DATETIME FORMAT, THEN CREATING A COLUNM APPREHENDED AGE AS INT

profile['Date Apprehended'] = pd.to_datetime(profile['Date Apprehended'], errors='coerce')
profile['Born Date'] = pd.to_datetime(profile['Born Date'], errors='coerce')

profile['Apprehended Age'] = ((profile['Date Apprehended'] - profile['Born Date']).dt.days // 365).astype('Int64')

# %%
profile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 711 entries, 0 to 710
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              711 non-null    object
#  1   Nicknames         469 non-null    object
#  2   Age               243 non-null    float64
#  3   Born Date         444 non-null    datetime64[ns]
#  4   Born Location     420 non-null    object
#  5   Died Date         308 non-null    object
#  6   Died Location     227 non-null    object
#  7   Conviction        502 non-null    object
#  8   Criminal Penalty  577 non-null    object
#  9   Date Apprehended  543 non-null    datetime64[ns]
#  10  born country      420 non-null    object
#  11  Apprehended Age   378 non-null    Int64
# dtypes: Int64(1), datetime64[ns](2), float64(1), object(8)
# memory usage: 67.5+ KB

# %%
profile['born country'].unique()
# Out:
# array(['Colombia', 'Pakistan', 'USSR', 'Brazil', 'India', 'Iran', 'China',
#        'Abul DjabarAfghanistan', None, 'Protectorate of Uganda',
#        'Soviet Union', 'Indonesia', 'South Africa', 'Byelorussian SSR',
#        'Morocco', 'Romania', 'Mexico', 'Russian Empire', 'Egypt',
#        'Greece', 'Maoupa Cedric MaakeSouth Africa', 'Canada', 'England',
#        'German Empire', 'Hungary', 'France', 'Ecuador', 'RSFSR',
#        'South Korea', 'Turkey', 'United States', 'Martinique', 'Peru',
#        'Ukrainian SSR', 'Italy', 'Imperial State of Iran', 'Spain',
#        'Elias XitavhudziUnion of South Africa', 'Uttar Pradesh',
#        'Argentina', 'Union of South Africa', 'Norway', 'Poland', 'Chile',
#        'Germany', 'French Tunisia', 'United States of Brazil',
#        'Venezuela', 'Tajik SSR', 'Latvia',
#        'Johannes MashianeSouth Africa', 'Georgian SSR',
#        'North German Confederation', 'Scotland', 'Yemen',
#        'occupied Austria', 'Belgium', 'Japan', 'So Paulo', 'Latvian SSR',
#        'UkSSR', 'Zhejiang', 'Kenya', 'Denmark', 'Texas', 'Czechoslovakia',
#        'Occupied Japan', 'Australia', 'Sweden', 'Empire of Japan', 'UK',
#        'Imperial Germany', 'Ontario Canada', 'Chongqing', 'East Germany',
#        'BSSR', 'Costa Rica', 'West Germany', 'Nigeria', 'Switzerland',
#        'Kingdom of Yugoslavia', 'German Confederation', 'Netherlands',
#        'Israel', 's Republic', 'Yugoslavia', 'Wales', 'Massachusetts',
#        'Slovakia', 'unknown', 'Nazi Germany', 'British Hong Kong',
#        'occupied Germany', 'Kingdom of Romania', 'Moldavian SSR', 's',
#        'FukuokaOccupied Japan', 'SFR Yugoslavia', 'Congress Poland',
#        'Cape Colony', 'Canary Islands',
#        'Socialist Federal Republic of Yugoslavia',
#        'Gabriel Garza HothMexico', 'United Kingdom', 'Hong Kong',
#        'Portugal', 'sMexico', 'US', 'New York', 'Malaysia',
#        'Grand Duchy of Hesse', 'Kingdom of Prussia', 'Singapore',
#        'TaeiIraq', 'Westphalia', 'Austria', 'Czech Republic', 'Ireland',
#        'centuryOttoman Empire', 'Rio de Janeiro', 'Guatemala',
#        'Uzbek SSR', 'Mxico', 'Russia', 'Territory of Hawaii'],
#       dtype=object)

# %%
to_continent = {
    'Colombia': 'South America',
    'Brazil': 'South America',
    'Argentina': 'South America',
    'Peru': 'South America',
    'Mexico': 'North America',
    'Canada': 'North America',
    'United States': 'North America',
    'US': 'North America',
    'Texas': 'North America',
    'New York': 'North America',
    'Massachusetts': 'North America',
    'England': 'Europe',
    'Scotland': 'Europe',
    'Wales': 'Europe',
    'United Kingdom': 'Europe',
    'UK': 'Europe',
    'France': 'Europe',
    'Germany': 'Europe',
    'Italy': 'Europe',
    'Poland': 'Europe',
    'Hungary': 'Europe',
    'Romania': 'Europe',
    'Russia': 'Europe',
    'USSR': 'Europe',
    'Soviet Union': 'Europe',
    'Byelorussian SSR': 'Europe',
    'Ukrainian SSR': 'Europe',
    'Tajik SSR': 'Asia',
    'Uzbek SSR': 'Asia',
    'Moldavian SSR': 'Europe',
    'Latvia': 'Europe',
    'Latvian SSR': 'Europe',
    'Georgian SSR': 'Europe',
    'RSFSR': 'Europe',
    'Imperial Germany': 'Europe',
    'German Empire': 'Europe',
    'German Confederation': 'Europe',
    'West Germany': 'Europe',
    'East Germany': 'Europe',
    'Austria': 'Europe',
    'occupied Austria': 'Europe',
    'Czechoslovakia': 'Europe',
    'Czech Republic': 'Europe',
    'Slovakia': 'Europe',
    'Portugal': 'Europe',
    'Belgium': 'Europe',
    'Netherlands': 'Europe',
    'Sweden': 'Europe',
    'Denmark': 'Europe',
    'Norway': 'Europe',
    'Ireland': 'Europe',
    'Switzerland': 'Europe',
    'Yugoslavia': 'Europe',
    'SFR Yugoslavia': 'Europe',
    'Socialist Federal Republic of Yugoslavia': 'Europe',
    'Kingdom of Yugoslavia': 'Europe',
    'Kingdom of Romania': 'Europe',
    'Israel': 'Asia',
    'Iran': 'Asia',
    'Imperial State of Iran': 'Asia',
    'India': 'Asia',
    'Pakistan': 'Asia',
    'Indonesia': 'Asia',
    'Malaysia': 'Asia',
    'China': 'Asia',
    'Singapore': 'Asia',
    'Japan': 'Asia',
    'Empire of Japan': 'Asia',
    'Occupied Japan': 'Asia',
    'FukuokaOccupied Japan': 'Asia',
    'TaeiIraq': 'Asia',
    'Turkey': 'Asia',
    'centuryOttoman Empire': 'Asia',
    'Afghanistan': 'Asia',
    'Abul DjabarAfghanistan': 'Asia',
    'Zhejiang': 'Asia',
    'Chongqing': 'Asia',
    'Egypt': 'Africa',
    'Morocco': 'Africa',
    'South Africa': 'Africa',
    'Maoupa Cedric MaakeSouth Africa': 'Africa',
    'Johannes MashianeSouth Africa': 'Africa',
    'Union of South Africa': 'Africa',
    'Elias XitavhudziUnion of South Africa': 'Africa',
    'Protectorate of Uganda': 'Africa',
    'Kenya': 'Africa',
    'Nigeria': 'Africa',
    'French Tunisia': 'Africa',
    'Cape Colony': 'Africa',
    'Australia': 'Oceania',
    'Martinique': 'North America',
    'Costa Rica': 'North America',
    'Guatemala': 'North America',
    'Venezuela': 'South America',
    'So Paulo': 'South America',
    'Rio de Janeiro': 'South America',
    'Mxico': 'North America',
    'sMexico': 'North America',
    'Gabriel Garza HothMexico': 'North America',
    'Hong Kong': 'Asia',
    'British Hong Kong': 'Asia',
    'Israel': 'Asia',
    's Republic': None,
    's': None,
    'None': None,
    'unknown': 'Unknown',
    'Territory of Hawaii': 'Oceania',
    'Ontario Canada': 'North America',
    'Grand Duchy of Hesse': 'Europe',
    'Kingdom of Prussia': 'Europe',
    'Westphalia': 'Europe',
    'North German Confederation': 'Europe',
    'Imperial Germany': 'Europe',
    'occupied Germany': 'Europe',
    'Congress Poland': 'Europe',
    'BSSR': 'Europe'
}

profile['Continent'] = profile['born country'].map(to_continent)

# %%
columnstoorder = ['Name', 
                  'Nicknames', 
                  'Age', 
                  'Born Date', 
                  'Born Location', 
                  'born country',
                  'Died Date', 
                  'Died Location',
                  'Date Apprehended', 
                  'Apprehended Age', 
                  'Conviction', 
                  'Criminal Penalty',
                  'Continent'
]

profile = profile[columnstoorder]
profile.columns = profile.columns.str.title()

# %%
profile.head(1)
# Out:
#             Name                                          Nicknames   Age  \
# 0  Luis Garavito  The Beast, Goofy, Conflict, Bonifacio Morera L...  66.0
#
#    Born Date            Born Location Born Country   Died Date  \
# 0 1957-01-25  Gnova, Quindo, Colombia     Colombia  2023-10-12
#
#           Died Location Date Apprehended  Apprehended Age Conviction  \
# 0  Valledupar, Colombia       1999-04-22               42        NaN
#
#   Criminal Penalty      Continent
# 0              NaN  South America

# %%
profile[profile['Apprehended Age']<20]
# Out:
#                                   Name  \
# 42              Bruce George Peter Lee
# 50               Juan Fernando Hermosa
# 134                    Denis Pischikov
# 212                      Edmund Kemper
# 389                       Robert Nixon
# 448                        Craig Price
# 450             Cayetano Santos Godino
# 455                     Peter Woodcock
# 459                     Jürgen Bartsch
# 476             Harvey Miguel Robinson
# 527                        Leon Dorsey
# 535                    William Heirens
# 541                     Erwin Hagedorn
# 658  Viktor Sayenko And Igor Suprunyuk
#
#                                              Nicknames   Age  Born Date  \
# 42                                                 NaN   NaN 1960-07-31
# 50                     Niño del Terror-Child of Terror  20.0 1976-02-28
# 134          The Shivering Creature, Urals Raskolnikov   NaN 1983-04-12
# 212  Co-ed Killer, Co-ed Butcher, Ogre of Aptos The...   NaN 1948-12-18
# 389                                    The Brick Moron  19.0 1919-07-19
# 448                                                NaN   NaN 1973-10-11
# 450                                                NaN  48.0 1896-10-31
# 455                                                NaN  71.0 1939-03-05
# 459             The Carnival Killer (Der Kirmesmörder)  29.0 1946-11-06
# 476                                                NaN   NaN 1974-12-06
# 527                Pistol Pete, The Blockbuster Killer  32.0 1975-11-17
# 535                                The Lipstick Killer  83.0 1928-11-15
# 541                                                NaN  20.0 1952-01-30
# 658                                                NaN   NaN 1988-03-01
#
#                                      Born Location      Born Country  \
# 42                             Manchester, England           England
# 50   Clemente Baquerizo, Los Ros Province, Ecuador           Ecuador
# 134             Bulanash, Sverdlovsk Oblast, RSFSR             RSFSR
# 212                                            NaN              None
# 389                                            NaN              None
# 448                                            NaN              None
# 450                        Buenos Aires, Argentina         Argentina
# 455                  Peterborough, Ontario, Canada            Canada
# 459                               occupied Germany  occupied Germany
# 476                                            NaN              None
# 527                                            NaN              None
# 535                                            NaN              None
# 541          Eberswalde, Brandenburg, East Germany      East Germany
# 658    Dnipropetrovsk, Ukrainian SSR, Soviet Union      Soviet Union
#
#       Died Date                           Died Location Date Apprehended  \
# 42          NaN                                     NaN       1979-12-04
# 50   1996-02-28  Nueva Loja, Sucumbos Province, Ecuador       1992-01-09
# 134         NaN                                     NaN       2003-04-05
# 212         NaN                                     NaN       1964-08-27
# 389  1939-06-16                                     NaN       1938-05-28
# 448         NaN                                     NaN       1989-09-05
# 450  1944-11-15                      Ushuaia, Argentina       1912-12-04
# 455  2010-03-05        Penetanguishene, Ontario, Canada       1957-01-21
# 459  1976-04-28                Eickelborn, West Germany       1966-01-01
# 476         NaN                                     NaN       1993-12-06
# 527  2008-08-12                                     NaN       1994-09-14
# 535  2012-03-05                                     NaN       1946-06-26
# 541  1972-09-15   Leipzig Prison, Leipzig, East Germany       1971-11-12
# 658         NaN                                     NaN       2007-07-23
#
#      Apprehended Age                                         Conviction  \
# 42                19                                Manslaughter, Arson
# 50                15                                             Murder
# 134               19                                             Murder
# 212               15                              First-Degree Murder ×
# 389               18                                             Murder
# 448               15                                                NaN
# 450               16                                                NaN
# 455               17                                                NaN
# 459               19                                             Murder
# 476               19     First Degree Murder Attempted Murder, Burglary
# 527               18                             Capital Murder, Murder
# 535               17                                             Murder
# 541               19  Murder With Aggravating Circumstances Seual Ab...
# 658               19  Premeditated Murder And Animal Cruelty Sayenko...
#
#                                       Criminal Penalty      Continent
# 42                       Indefinite hospital detention         Europe
# 50                                4 years imprisonment            NaN
# 134                                  life imprisonment         Europe
# 212                                                NaN            NaN
# 389                                              death            NaN
# 448                                                NaN            NaN
# 450                                                NaN  South America
# 455                                                NaN  North America
# 459  life imprisonment, commuted 10 years of juveni...         Europe
# 476                                              death            NaN
# 527  60 years (Chon murder), death(Lindsey and Arms...            NaN
# 535                                  life imprisonment            NaN
# 541                                              death         Europe
# 658  life imprisonment for Sayenko and Suprunyuk, n...         Europe

# %%
profile['Criminal Penalty'].unique()
# Out:
# array([nan,
#        '7 years imprisonment in Colombia, extended to 9 due to in-prison homicide (1969 to 1978), 16 years imprisonment in Ecuador, released after 14 years (1980 to 1994), committed to mental hospital in Colombia (1994 to 1998)',
#        'death', 'life imprisonment',
#        '25 years imprisonment, 16 years imprisonment',
#        '30 years imprisonment (1973 to 2007), 8 years imprisonment (7 served on good behavior, 2011 to 2018)',
#        'Four life sentence(s) without the possibility of parole',
#        'death, commuted to life imprisonment',
#        '113 years imprisonment, released after 27 years',
#        '49 life sentence(s) without the possibility of parole',
#        '2,410 years imprisonment', '60 years imprisonment',
#        'Execution by hanging', '580 years imprisonment',
#        '34 years in jail',
#        '14 years in prison (died with pending criminal cases)',
#        '1 340 years imprisonment',
#        'life imprisonment with no possibility of parole for 25 years',
#        'Indefinite hospital detention',
#        'Eight consecutive life sentence(s) without the possibility of parole',
#        '4 years imprisonment', 'deathplus 8 life sentence(s)',
#        'Civil commitment', '25 years in prison',
#        'Los Angeles County, death(March 12, 1982)Orange County, death(August 26, 1983)',
#        'deathpenalty',
#        'Three death sentences (two in 1979, one in 1980) 1 to 15 years in prison (1976)',
#        'deathpenalty (commuted to life imprisonment)',
#        '25 years to life imprisonment',
#        'Illinois, death(October 3, 1986)Indiana, 60 years imprisonment (December 28, 1990)',
#        'death(commuted to life imprisonment)', '137 years imprisonment',
#        '25 years imprisonment', 'life imprisonment plus 99 years',
#        '40 years in prison',
#        '16 life sentence(s) + 140 years imprisonment',
#        '140 years (, 5 life sentence(s))',
#        '19 life sentence(s) plus 189 years imprisonment',
#        '35 years in prison', '461 years imprisonment without parole',
#        '13 terms of life imprisonment', '20 years', '759 years',
#        'life imprisonment without the possibility of parole',
#        'life imprisonment(506 years)',
#        'life imprisonment without the possibility of parole (x16, total of 941 years imprisonment)',
#        '440 years imprisonment', 'death(October 12, 1984)',
#        'deathby hanging',
#        'life imprisonment without the possibility of parole for 50 years',
#        '408 years imprisonment,Spokane County2. death(commuted to life), Pierce County',
#        'death(1976 and 1983)', 'Confined to a mental institution',
#        'Capital punishment in May 1994, commuted to life imprisonment',
#        '60 years, life imprisonment without parole',
#        'life imprisonment with the possibility of parole after 40 years imprisonment (murder)20 years imprisonment (rape)10 years imprisonment (attempted murder)',
#        'life imprisonment (8 counts)',
#        'life imprisonment without parole (or a term amounting to 250 years)',
#        'Committed to a psychiatric hospital', 'Life',
#        'life imprisonment (whole life order)',
#        'deathpenalty on October 26, 1995 (de jure)', '19 death sentences',
#        '13 consecutive life sentence(s) without the possibility of parole plus 8 years',
#        '11 life sentence(s)', 'Compulsory treatment',
#        '13 life sentence(s) (208 years for armed robbery)',
#        'deathsentence', 'Ten life sentence(s)',
#        '12 years (c. 1975)10 years (c. 1987), life imprisonment (2004)1 year (2010)20 years (2014)',
#        'Died by suicide before he could be sentenced',
#        'life imprisonment (whole life tariff)',
#        '60 years (overturned), life imprisonment', '25 years',
#        'death(30 November 1921)',
#        'life imprisonment (plus accessory of indeterminate reclusion)[note 1]',
#        'Declared insane, confined to a Psychiatric hospital',
#        'life imprisonment (x11)',
#        'Six death sentences and 40 years imprisonment, commuted to life imprisonment',
#        '268 years imprisonment', 'Never sentenced',
#        'Not guilty by reason of insanity', 'death(July 25, 1986)',
#        '7 life sentence(s)', '19 years imprisonment',
#        '16 life sentence(s), 220 years imprisonment',
#        'life imprisonment without the possibility of parole for 175 years(10 consecutive life sentence(s))',
#        'Life sentence', 'Psychiatric imprisonment 5 years in prison',
#        '20 years imprisonment', 'Execution by lethal injection',
#        'life imprisonment (25 years for murder, 10 years for kidnap)',
#        '203 years to life imprisonment',
#        'death, commuted to life with parole (1966) death(1993)',
#        'death, overturned and re-sentenced to life imprisonment',
#        'life imprisonment (Pittman)', '13 consecutive life terms',
#        '45 years in prison',
#        'life imprisonment (served in Leopoldov, Slovakia)',
#        'life imprisonment without parole',
#        'life imprisonment (without parole)',
#        'Two death sentences plus four life sentence(s), commuted to six life sentence(s) without the possibility of parole (murder convictions) 20 years in prison (arson conviction)',
#        'life imprisonment x4 (March 23, 1981 & September 1986), death(July 17, 1984 & February 27, 1997)',
#        'death, commuted to 15 years imprisonment and released in 2012',
#        '15 years imprisonment, commuted to 9 years imprisonment',
#        'Life (Leonard Christopher)',
#        'KansasdeathMissouriLife without parole', '20 years probation',
#        '20 years to life',
#        'ConnecticutdeathNew York8 and 1/3 to 25 years imprisonment',
#        'None (died before trial)',
#        'Life without the possibility of parole, probation or suspension of sentence',
#        'Interned in a mental institution for life',
#        'deathplus four life sentence(s)',
#        'life imprisonment with a possibility of parole after 40 years',
#        '7 life sentence(s) without parole (murder)6 years imprisonment (attempted murder)6 years imprisonment (false imprisonment)6 years imprisonment (robbery)',
#        '7 life terms plus 20 years',
#        'Seven consecutive life sentence(s) without the possibility of parole',
#        'Detention at Broadmoor Hospital but moved to Thornford Park Hospital',
#        '25 years imprisonment (1982, paroled after 21 years)Six consecutive life sentence(s) without the possibility of parole (2008)',
#        '6 life sentence(s) without parole plus 25 years',
#        'Arizona, 15 years imprisonmentSouth Carolina, life imprisonment without parole',
#        'Life in prison without parole(seven concurrent terms)',
#        '6 death sentences',
#        'deathpenalty (nullified by a presidential pardon)Life in prison',
#        'Life without parole', 'Never tried', 'death, commuted to life',
#        '22 years to life imprisonment (5 April 2001)',
#        '7 life sentence(s), effectively 40 years',
#        '8 life sentence(s) + 139 years', 'death(September 20, 2000)',
#        'None (Killed himself before sentencing)', '40 years imprisonment',
#        '6 life sentence(s) without the possibility of parole',
#        '110 years imprisonment', 'deathPenalty (de jure)',
#        'life imprisonment without parole (1988)',
#        'life imprisonment with the possibility of parole after 25 years',
#        'life imprisonment x6', '142 years and 3 months imprisonment',
#        'death, commuted to Life', 'death(January 27, 1984)',
#        'Committed suicide before apprehension',
#        '15 years in prison and detention in a psychiatric hospital',
#        '150 years to life imprisonment',
#        'Two death sentences (August 1997 & 1999)',
#        'Life sentence, effectively 42 years', '8 years imprisonment',
#        '15 years in prison',
#        'Military, 4 years imprisonmentIllinois, 35 years imprisonmentIndianaLife without parole',
#        'deathby lethal injection',
#        'life imprisonment without the possibility of parole for 25 years',
#        'FederaldeathIdaho and California, life imprisonment without the possibility of parole',
#        'death, commuted to 20 years imprisonment (1974), 20 years imprisonment (1983)',
#        'life imprisonment x4 death',
#        '5 terms of 30 years to life for aggravated murder 15 years additional for gun specification',
#        '47 years', 'life imprisonment (minimum of 60 years)',
#        'death(September 26, 1998)',
#        '35 years in prison (1986, paroled after 11 years) deathplus three life sentence(s) without the possibility of parole (1999)',
#        'deathby electrocution',
#        'Suffolk County:death, commuted to life imprisonmentWestchester County:25 years-to-, life imprisonment',
#        '5 life sentence(s)',
#        'life imprisonment with 18 years security period',
#        'death, commuted to 20 years in prison (murders), 15 years imprisonment (prison assaults)',
#        'Compulsory medical measures (1992) 10 years of imprisonment (1997) Involuntary commitment to the Kamyshin psychiatric hospital of federal service of completing punishment (1999)',
#        '70 years imprisonment', 'Two life sentence(s) plus 26 years',
#        'death(Fefferman case), life imprisonment',
#        'Pennsylvania, life imprisonmentMaryland40 years',
#        'FederalLife without paroleCaliforniadeath',
#        '21 years term imprisonment (1979), death(August 27, 1986)',
#        '10 years imprisonment Murder × 4 (1986)Imprisoned for 25–life Check bouncing (2001)',
#        '5 × life imprisonment + 25 years',
#        'death, commuted to 120 years imprisonment',
#        'death(November 15, 2004)',
#        'life imprisonment (currently serving in Ilava, Slovakia)',
#        'death(November 4, 1994)', 'death(de jure)',
#        'life imprisonment, commuted to 18 years imprisonment',
#        'Four life sentence(s)',
#        '4 consecutive life sentence(s) without the possibility of parole',
#        'Closed psychiatric treatment',
#        'death, commuted to life imprisonment without parole',
#        'life imprisonment, commuted 10 years of juvenile detention',
#        '4 life sentence(s)14 years in prison',
#        'Four life sentence(s)(min. 35 years)', 'life imprisonment x4',
#        '300 years in prison', 'Four consecutive life sentence(s)',
#        '52 years in prison', '2 × life sentence(s)',
#        'Committed to mental facility',
#        'life imprisonment, 20-years minimum term',
#        '232 years imprisonment', 'Whole life tariff',
#        '3 × life imprisonment without parole',
#        'life imprisonment, commuted to 28.5 years imprisonment',
#        'life imprisonment (June 6, 1984)deathby electric chair (November 26, 1985)',
#        '4x life imprisonment plus 27 years without parole[citation needed]',
#        'deathby gas chamber', '160 years imprisonment',
#        'death(December 1978 & August 1986)',
#        'life imprisonment(Denton murder) death(Logan murder)', 'Hanging',
#        'CaliforniadeathFlorida, life imprisonment',
#        'Federal, life imprisonmentMississippideathFlorida, life imprisonment',
#        'Three years of probation',
#        'Territory of Alaskadeath, commuted to 15 years imprisonmentWashington, 15 years imprisonmentMinnesota, life imprisonment',
#        'NebraskadeathMaine, life imprisonment',
#        'life imprisonment with a whole-life order',
#        '33 years of detention',
#        'Several consecutive life sentence(s) without the possibility of parole[a]',
#        '60 years (Chon murder), death(Lindsey and Armstrong murders)',
#        'Detained at His Majestys pleasure (17 October 1951) death(24 July 1952) Commuted to life imprisonment (29 August 1952)',
#        'death, commuted to 98 years imprisonment', '58 years in prison',
#        '75 years to life in prison',
#        'life imprisonment x3, non-parole period of 30 years',
#        'Indefinite detention in a psychiatric hospital',
#        'life imprisonment plus 25 years', '103 years in prison',
#        'life imprisonment x3', '2 × life imprisonment + 40 years',
#        'life imprisonment (x2) (overturned)Psychiatric imprisonment',
#        'death(November 24, 1998 & November 1, 2002)',
#        '60 years in prison, maximum penalty in this time in Mexico City.',
#        'Institutionalized in the Mendota Mental Health Institute',
#        '70 years in prison', 'death(July 6, 1999)',
#        '15 years imprisonment',
#        '16 years, 3 months with the possibility of parole',
#        '10 years to life in prison', 'death(November 2, 1984)',
#        '15 years imprisonment with hard labour',
#        'Federal, 30 years imprisonmentPennsylvaniaThree consecutive life sentence(s) without the possibility of parole',
#        '28 consecutive life sentence(s) plus $270,000 in fines',
#        '18 consecutive life sentence(s)', '21 years imprisonment',
#        '127 years and a half imprisonment',
#        '25 years imprisonment + 10 years of involuntary commitment',
#        'Involuntary commitment', 'life imprisonment(whole life order)',
#        '360 years imprisonment',
#        'Six consecutive life sentence(s) without the possibility of parole',
#        'Four consecutive life sentence(s) without parole, plus 20 years',
#        'life imprisonment x2 (reduced to 18 years)', '4 years in jail',
#        'death, later sent to insane asylum', 'Lifetime',
#        'Life plus 60 years',
#        'New YorkLife without paroleOhio20 years to life',
#        '76 years in prison', '50 years to life in prison',
#        '13 life sentence(s), 4 counts of murder, 5 counts of attempted murder, 6 counts of GBH',
#        '110 years of imprisonment', '120 years imprisonment',
#        '99 years with triple credit',
#        'life imprisonment with a minimum tariff of 30 years',
#        'Died before being convicted',
#        'life imprisonment for Sayenko and Suprunyuk, nine years imprisonment for Hanzha',
#        '77 years in prison',
#        'Robin Gecht, 120 years imprisonmentAndrew KokoraleisdeathThomas Kokoraleis, life imprisonment without the possibility of parole, commuted to 70 yearsEdward Spreitzerdeath, commuted to life imprisonment without the possibility of parole',
#        'Volkovich:, life imprisonment',
#        'Died by suicide prior to murder conviction',
#        'Linwood and Jamesdeathby electrocutionAnthony, life imprisonment',
#        'life imprisonment (without parole) (Buono), life imprisonment (Bianchi)',
#        'death(Gerald)', '50 years in prison', '40 in prison',
#        '445 years imprisonment',
#        'life imprisonment (Árpád Kiss, István Kiss, Zsolt Pető), 13 years imprisonment (István Csontos)',
#        'life imprisonment (Anoufriev)24 years imprisonment, later changed to 20 years (Lytkin)',
#        'death(de jure, 1981)',
#        'life imprisonment (Graham)20 to 40 years imprisonment (Wood)',
#        '78 years (overturned) 14 years, paroled after 11 years',
#        'Four terms of life imprisonment',
#        'life imprisonment (both Duffy and Mulcahy)',
#        'death(September 22, 1983)',
#        'life imprisonment with a possibility of parole after 25 years, including a dangerous offender designation, in 1995',
#        '75 years to life'], dtype=object)

# %%
# CLASSIFYING CATEGORIES FOR THE PENALTIES

penalty_categories = {'death': [],
            'life_imprisonment': [],
            'years_imprisonment': [],
            'hospital_detention': [],
            'not_sentenced': [],
            'suicide_or_died_before_sentence': []}

# %%
# SORTING THE COLUMN TO ASSIGN TO THE CATEGORIES BASED ON KEY WORKDS - ADDING TEXTING FORMATATION AND RETURING NONE TO NULLS

def categorize_sentence(sentence):
    if pd.isna(sentence):
        return None
    s = str(sentence).lower()
    if any(term in s for term in ['death', 'execution', 'hanging', 'electrocution', 'lethal injection', 'gas chamber']):
        return 'death'
    elif 'life' in s:
        return 'life_imprisonment'
    elif 'year' in s or 'years' in s:
        return 'years_imprisonment'
    elif any(term in s for term in ['hospital', 'psychiatric', 'mental']):
        return 'hospital_detention'
    elif any(term in s for term in ['never sentenced', 'never tried', 'not guilty by reason of insanity']):
        return 'not_sentenced'
    elif any(term in s for term in ['died', 'suicide', 'killed himself']):
        return 'suicide_or_died_before_sentence'
    else:
        return 'other'  # ou None se preferir deixar sem categoria

# Criar a nova coluna com as categorias
profile['Criminal Penalty Categories'] = profile['Criminal Penalty'].apply(categorize_sentence)

# %%
profile['Criminal Penalty Categories'].value_counts()
# Out:
# Criminal Penalty Categories
# death                              247
# life_imprisonment                  237
# years_imprisonment                  66
# hospital_detention                   9
# other                                7
# suicide_or_died_before_sentence      6
# not_sentenced                        5
# Name: count, dtype: int64

# %%
# SAVING CLEAN FILE
profile.to_csv('../Clean Files/Profile/1V-profile_killers.csv', index=False)

# %%
# SAVING CLEAN FILE
profile.to_csv('../Clean Files/Profile/1V-profile_killers.csv', index=False)

# %%
# SAVING CLEAN FILE
profile.to_csv('../Clean Files/Profile/1V-profile_killers.csv', index=False)

# %% [markdown]
# ### EDA VICTIMS:

# %%
victims = pd.read_csv('../Clean Files/Victims/0V-serial_killers_by_victims.csv')

# %%
# IDENTIFYING ALL UNIQUE VALUES TO HELP WITH DICTIONARY CREATION

list(victims['Country'].unique())
# Out:
# ['Colombia, Ecuador, Venezuela',
#  'Colombia, Peru, Ecuador',
#  'Pakistan',
#  'Russia',
#  'Colombia, Ecuador, Brazil',
#  'Brazil',
#  'India',
#  'Iran',
#  'China',
#  'Afghanistan',
#  'United States',
#  'Belgian Congo, Tanganyika',
#  'Soviet Union',
#  'Soviet Union, Ukraine',
#  'Indonesia',
#  'South Africa',
#  'Morocco',
#  'Kingdom of Romania, Yugoslavia, Hungary',
#  'Mexico',
#  'Ottoman Empire, Iraq, Iran',
#  'Egypt',
#  'Germany',
#  'Colombia',
#  'Zambia',
#  'Swaziland',
#  'Greece',
#  'Canada',
#  'United Kingdom',
#  'Austria-Hungary',
#  'France, Germany, Switzerland',
#  'Ecuador',
#  'United States, Canada',
#  'Soviet Union, Russia, Tajikistan',
#  'Romania',
#  'South Korea',
#  'Costa Rica',
#  'Soviet Union, Russia',
#  'Latvia',
#  'Turkey',
#  'France',
#  'Sri Lanka',
#  'Peru',
#  'Ukraine',
#  'Italy',
#  'France, Belgium',
#  'Spain',
#  'United States, Mexico',
#  'Argentina',
#  'Poland',
#  'Chile',
#  'West Germany',
#  'Tunisia',
#  'Venezuela',
#  'Rwanda',
#  'Thailand, Nepal, India, Malaysia',
#  'Yemen',
#  'Japan',
#  'Austria, United States, Czechoslovakia',
#  'Belgium',
#  'Bangladesh',
#  'Czechoslovakia',
#  'Soviet Union, Russia, Ukraine',
#  'Kenya',
#  'German Empire, Germany',
#  'Denmark',
#  'Ecuador, Spain',
#  'Czechoslovakia, Germany, Netherlands',
#  'Sweden',
#  'China, Japan',
#  'Australia',
#  'Spain, France, Italy',
#  'Canada, United States',
#  'Cyprus',
#  'Italy, France',
#  'East Germany, Germany, France, Spain, Czech Republic, Italy',
#  'Belarus',
#  'East Germany, Germany',
#  'Estonia',
#  'United States, Portuguese Angola',
#  'Switzerland, France, United States, Yugoslavia, Italy',
#  'West Germany, United States',
#  'Netherlands',
#  'SR Croatia',
#  'Panama',
#  'Singapore',
#  'Belize',
#  'SR Slovenia',
#  'Namibia',
#  'United Kingdom, Ireland, West Germany, Netherlands, France',
#  'Austria',
#  'Hong Kong',
#  'Israel',
#  'Allied-occupied Germany, West Germany',
#  'Republic of Macedonia',
#  'East Germany',
#  'SR Slovenia, Serbia and Montenegro, Slovenia',
#  'Portugal',
#  'Malaysia',
#  'United States, Austria, France, United Kingdom',
#  'Singapore, Malaysia',
#  'Kingdom of Yugoslavia',
#  'Iraq',
#  'Norway',
#  'Switzerland',
#  'Czech Republic',
#  'Imperial State of Iran',
#  'Finland',
#  'United States, Zimbabwe',
#  'Hungary',
#  'Belgium, France',
#  'Guatemala',
#  'Uzbekistan, Kazakhstan',
#  'Italy, West Germany, Netherlands']

# %%
# DICTIONARY CREATION CATEGORIZING COUNTRIES BY CONTINENT, INCLUDING MULTIPLE CONTINENTS

country_to_continent = {
    'Colombia, Ecuador, Venezuela': 'South America',
    'Colombia, Peru, Ecuador': 'South America',
    'Pakistan': 'Asia',
    'Russia': 'Europe',
    'Colombia, Ecuador, Brazil': 'South America',
    'Brazil': 'South America',
    'India': 'Asia',
    'Iran': 'Asia',
    'China': 'Asia',
    'Afghanistan': 'Asia',
    'United States': 'North America',
    'Belgian Congo, Tanganyika': 'Multiple continents',
    'Soviet Union': 'Multiple continents',
    'Soviet Union, Ukraine': 'Multiple continents',
    'Indonesia': 'Asia',
    'South Africa': 'Africa',
    'Morocco': 'Africa',
    'Kingdom of Romania, Yugoslavia, Hungary': 'Europe',
    'Mexico': 'North America',
    'Ottoman Empire, Iraq, Iran': 'Multiple continents',
    'Egypt': 'Africa',
    'Germany': 'Europe',
    'Colombia': 'South America',
    'Zambia': 'Africa',
    'Swaziland': 'Africa',
    'Greece': 'Europe',
    'Canada': 'North America',
    'United Kingdom': 'Europe',
    'Austria-Hungary': 'Multiple continents',
    'France, Germany, Switzerland': 'Europe',
    'Ecuador': 'South America',
    'United States, Canada': 'North America',
    'Soviet Union, Russia, Tajikistan': 'Multiple continents',
    'Romania': 'Europe',
    'South Korea': 'Asia',
    'Costa Rica': 'North America',
    'Soviet Union, Russia': 'Multiple continents',
    'Latvia': 'Europe',
    'Turkey': 'Asia',
    'France': 'Europe',
    'Sri Lanka': 'Asia',
    'Peru': 'South America',
    'Ukraine': 'Europe',
    'Italy': 'Europe',
    'France, Belgium': 'Europe',
    'Spain': 'Europe',
    'United States, Mexico': 'North America',
    'Argentina': 'South America',
    'Poland': 'Europe',
    'Chile': 'South America',
    'West Germany': 'Europe',
    'Tunisia': 'Africa',
    'Venezuela': 'South America',
    'Rwanda': 'Africa',
    'Thailand, Nepal, India, Malaysia': 'Asia',
    'Yemen': 'Asia',
    'Japan': 'Asia',
    'Austria, United States, Czechoslovakia': 'Europe',
    'Belgium': 'Europe',
    'Bangladesh': 'Asia',
    'Czechoslovakia': 'Europe',
    'Soviet Union, Russia, Ukraine': 'Multiple continents',
    'Kenya': 'Africa',
    'German Empire, Germany': 'Europe',
    'Denmark': 'Europe',
    'Ecuador, Spain': 'South America',
    'Czechoslovakia, Germany, Netherlands': 'Europe',
    'Sweden': 'Europe',
    'China, Japan': 'Asia',
    'Australia': 'Oceania',
    'Spain, France, Italy': 'Europe',
    'Canada, United States': 'North America',
    'Cyprus': 'Asia',
    'Italy, France': 'Europe',
    'East Germany, Germany, France, Spain, Czech Republic, Italy': 'Europe',
    'Belarus': 'Europe',
    'East Germany, Germany': 'Europe',
    'Estonia': 'Europe',
    'United States, Portuguese Angola': 'North America',
    'Switzerland, France, United States, Yugoslavia, Italy': 'Europe',
    'West Germany, United States': 'Europe',
    'Netherlands': 'Europe',
    'SR Croatia': 'Europe',
    'Panama': 'North America',
    'Singapore': 'Asia',
    'Belize': 'North America',
    'SR Slovenia': 'Europe',
    'Namibia': 'Africa',
    'United Kingdom, Ireland, West Germany, Netherlands, France': 'Europe',
    'Austria': 'Europe',
    'Hong Kong': 'Asia',
    'Israel': 'Asia',
    'Allied-occupied Germany, West Germany': 'Multiple continents',
    'Republic of Macedonia': 'Europe',
    'East Germany': 'Europe',
    'SR Slovenia, Serbia and Montenegro, Slovenia': 'Europe',
    'Portugal': 'Europe',
    'Malaysia': 'Asia',
    'United States, Austria, France, United Kingdom': 'North America',
    'Singapore, Malaysia': 'Asia',
    'Kingdom of Yugoslavia': 'Europe',
    'Iraq': 'Asia',
    'Norway': 'Europe',
    'Switzerland': 'Europe',
    'Czech Republic': 'Europe',
    'Imperial State of Iran': 'Multiple continents',
    'Finland': 'Europe',
    'United States, Zimbabwe': 'North America',
    'Hungary': 'Europe',
    'Belgium, France': 'Europe',
    'Guatemala': 'North America',
    'Uzbekistan, Kazakhstan': 'Asia',
    'Italy, West Germany, Netherlands': 'Europe'
}

# %%
# APPLYING THE COLUMN CREATION TO ADD CONTINENT

victims['Continent'] = victims['Country'].map(country_to_continent)

# %%
# CONFIRMING THE CHANGE AND COUNTING VALUES

victims['Continent'].value_counts()
# Out:
# Continent
# North America          325
# Europe                 214
# Asia                    95
# Africa                  39
# South America           33
# Multiple continents     31
# Oceania                 20
# Name: count, dtype: int64

# %%
# FUNCTION TO CATEGORIZE COUNTRIES AS UNIQUE OR MULTIPLE COUNTRIES:

def categorize_multiple_countries(country_series):
    return country_series.apply(lambda x: "Multiple Countries" if ',' in x else x)

# %%
# APPLYING THE CATEGORIES TO CREATE THE NEW COLUMN 'COUNTRY SORTED'

victims['Country sorted'] = categorize_multiple_countries(victims['Country'])

# %%
# CONFIRM COLUMN CREATING, AND CHECKING NULLS AND DATA TYPE

victims.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 757 entries, 0 to 756
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              757 non-null    object
#  1   Country           757 non-null    object
#  2   Start year        738 non-null    float64
#  3   End year          740 non-null    float64
#  4   Proven victims    757 non-null    float64
#  5   Possible victims  757 non-null    float64
#  6   Notes             754 non-null    object
#  7   Continent         757 non-null    object
#  8   Country sorted    757 non-null    object
# dtypes: float64(4), object(5)
# memory usage: 53.4+ KB

# %%
# CONVERTING FLOATS TO INTEGER

victims[['Start year', 'End year', 'Proven victims', 'Possible victims']] = victims[['Start year', 'End year', 'Proven victims', 'Possible victims']].astype('Int64')

# %%
# CREATING COLUMN OF MEDIAN YEARS OF THE CRIMES:

victims['Median Year'] = (victims['Start year'] + victims['End year']) / 2

victims['Median Year'] = victims['Median Year'].astype('Int64')

# %%
# CREATING COLUMN DECADE AND CONFERTING AS STRING

victims['Decade'] = (victims['Median Year'] // 10) * 10

victims['Decade'] = victims['Decade'].astype('Int64').astype(str) + 's'

victims['Decade'] = victims['Decade'].replace('<NA>', 'Unknown')

# %%
victims.sample(20)
# Out:
#                                     Name   Killer Type  \
# 657                        Sonya Caleffi        Female
# 279              Manuel Delgado Villegas          Male
# 198                       Yevgeny Petrov          Male
# 241       Edgecombe County Serial Killer  Unidentified
# 538                         "Bible John"          Male
# 632                       Stephan Letter          Male
# 382                 Joseph E. Duncan III          Male
# 18                            Wang Qiang          Male
# 472                          Lam Kor-wan          Male
# 501                      Bernhard Prigan          Male
# 311                        Václav Mrázek          Male
# 586            Mario Alberto Sulú Canché          Male
# 745  Loren Herzog and Wesley Shermantine    Male Group
# 150                     Tamara Samsonova        Female
# 636                      Roger Andermatt          Male
# 211                 Nikolai Dzhumagaliev          Male
# 282                           Ivan Milat          Male
# 635                       Arnfinn Nesset          Male
# 396                   Honolulu Strangler          Male
# 160                       Thozamile Taki          Male
#
#                                    Country      Country Sorted  \
# 657                                  Italy               Italy
# 279                   Spain, France, Italy  Multiple Countries
# 198                                 Russia              Russia
# 241                          United States       United States
# 538                         United Kingdom      United Kingdom
# 632                                Germany             Germany
# 382                          United States       United States
# 18                                   China               China
# 472                              Hong Kong           Hong Kong
# 501  Allied-occupied Germany, West Germany  Multiple Countries
# 311                         Czechoslovakia      Czechoslovakia
# 586                                 Mexico              Mexico
# 745                          United States       United States
# 150                                 Russia              Russia
# 636                            Switzerland         Switzerland
# 211                           Soviet Union        Soviet Union
# 282                              Australia           Australia
# 635                                 Norway              Norway
# 396                          United States       United States
# 160                           South Africa        South Africa
#
#                Continent  Start Year  End Year  Median Year  Years Active  \
# 657               Europe        2003      2004         2003             1
# 279               Europe        1964      1971         1967             7
# 198               Europe        1998      2003         2000             5
# 241        North America        2000      <NA>         <NA>          <NA>
# 538               Europe        1968      1969         1968             1
# 632               Europe        2003      2004         2003             1
# 382        North America        1996      2005         2000             9
# 18                  Asia        1995      2003         1999             8
# 472                 Asia        1980      <NA>         <NA>          <NA>
# 501  Multiple continents        1947      1952         1949             5
# 311               Europe        1951      1956         1953             5
# 586        North America        2007      2008         2007             1
# 745        North America        1984      1999         1991            15
# 150               Europe        1995      2015         2005            20
# 636               Europe        1995      2001         1998             6
# 211  Multiple continents        1979      1991         1985            12
# 282              Oceania        1990      <NA>         <NA>          <NA>
# 635               Europe        <NA>      1983         <NA>          <NA>
# 396        North America        1985      1986         1985             1
# 160               Africa        2007      2016         2011             9
#
#     Decade  Total Victims (Unproven + Proven)  Unproven Possible Victims  \
# 657  2000s                                 18                         13
# 279  1960s                                 48                         41
# 198  2000s                                 11                          0
# 241  <NA>s                                 10                          1
# 538  1960s                                  3                          0
# 632  2000s                                 29                          0
# 382  2000s                                  7                          2
# 18   1990s                                 60                         15
# 472  <NA>s                                  4                          0
# 501  1940s                                 16                         13
# 311  1950s                                  7                          0
# 586  2000s                                  3                          0
# 745  1990s                                 19                         15
# 150  2000s                                 13                          0
# 636  1990s                                 22                          0
# 211  1980s                                 10                          0
# 282  <NA>s                                 30                         23
# 635  <NA>s                                 82                         60
# 396  1980s                                  5                          0
# 160  2010s                                 13                          0
#
#      Proven Victims                                              Notes
# 657               5  Nurse who poisoned terminally-ill patients; se...
# 279               7  Wandering criminal known as El Arropiero ("The...
# 198              11  Known as the "Novouralsk Ripper"; a child rapi...
# 241               9  Unidentified serial killer who killed nine wom...
# 538               3  Unidentified serial killer who murdered three ...
# 632              29  Nurse who killed 29 patients; sentenced to lif...
# 382               5  Convicted of killing a California boy in 1997 ...
# 18               45  Wang killed 45 and raped 10 from 1995 to 2003....
# 472               4  Taxi driver and one of Hong Kong's only two kn...
# 501               3  Killed women near highways; confessed to a tot...
# 311               7      Killed 7 women in Chomutov. Executed in 1957.
# 586               3  Killed 3 women from 2007 to 2008; later commit...
# 745               4  Known as the "Speed Freak Killers"; California...
# 150              13  Known as the "Granny Ripper"; killed and alleg...
# 636              22  Known as the "Death-Keeper of Lucerne"; nurse ...
# 211              10  Lured women in a park at night and hacked them...
# 282               7  Convicted of the Backpacker murders; sentenced...
# 635              22  Norwegian nurse and most prolific known serial...
# 396               5  Raped and strangled five young women in Hawaii...
# 160              13  Known as the "Sugar cane serial killer", he mu...

# %%
victims.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 757 entries, 0 to 756
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Name                               757 non-null    object
#  1   Killer Type                        757 non-null    object
#  2   Country                            757 non-null    object
#  3   Country Sorted                     757 non-null    object
#  4   Continent                          757 non-null    object
#  5   Start Year                         738 non-null    Int64
#  6   End Year                           740 non-null    Int64
#  7   Median Year                        723 non-null    Int64
#  8   Years Active                       723 non-null    Int64
#  9   Decade                             757 non-null    object
#  10  Total Victims (Unproven + Proven)  757 non-null    Int64
#  11  Unproven Possible Victims          757 non-null    Int64
#  12  Proven Victims                     757 non-null    Int64
#  13  Notes                              754 non-null    object
# dtypes: Int64(7), object(7)
# memory usage: 88.1+ KB

# %%
# CREATING DICTIONARY AND APPKYING TO CATEGORIZE KILLERS BY GENRE

female_killers = [
    'Marie Fikáčková', 'Ivanova and Olga Tamarin', 'Gwendolyn Graham and Catherine May Wood',
    'Felícitas Sánchez Aguillón', 'Delfina and María de Jesús González', 'Angel Makers of Nagyrév',
    'Lainz Angels of Death', 'Silvia Merez Cult', 'Amelia Sach and Annie Walters', 'Belle Gunness',
    'Aileen Wuornos', 'Dorothea Puente', 'Juana Barraza', 'Jane Toppan', 'Genene Jones',
    'Beverley Allitt', 'Enriqueta Martí', 'Tillie Klimek', 'Mariane Nölle', 'Vickie Dawn Jackson',
    'Joan Vila', 'Linda Hazzard', 'Ann Arber Hospital Killer', 'Elizabeth Wettlaufer', 'Velma Barfield',
    'Lyda Southard', 'Shirley Winters', 'Francisca Ballesteros', 'Valery Asratyan', 'Martha Rendell',
    'Sharon Kinne', 'Leonarda Cianciulli', 'Bertha Gifford', 'Rhonda Belle Martin', 'Reta Mays',
    'Marybeth Tinning', 'Jeanne Weber', 'Marie Alexandrine Becker', 'Antoinette Scieri', 'Kristen Gilbert',
    'Sonya Caleffi', 'Kimberly Clark Saenz', 'Vera Renczi', 'Mariam Soulakiotis', 'Irina Gaidamachuk',
    'Tamara Samsonova', 'Celine Lesage', 'Elisabeth Wiese', 'Anna Marie Hahn', 'Waneta Hoyt',
    'Lucy Letby', 'Frans Hooijmaijers', 'Miyuki Ishikawa', 'Amy Archer-Gilligan', 'Aino Nykopp-Koski',
    'Elfriede Blauensteiner', 'Joanna Dennehy', 'Mary Elizabeth Wilson'
]

gangs = [
    "Raya and Sakina and their husbands", "Beasts of Satan", "Chijon Family", "The Family",
    "Ian Brady and Myra Hindley", "Ray and Faye Copeland", "The Skin Hunters", "The Hernández Brothers Sect",
    "The Ciudad Juárez Rebels", "Tadeusz Grzesik and the Bureaucrats Gang", "The Manson Family cult killings",
    "National Socialist Underground", "Joshi-Abhyankar serial murderers", "Hillside Stranglers",
    "Bloody Benders", "The Cleaners", "Lainz Angels of Death", "Death Angels", "Ripper Crew",
    "Anísio Ferreira de Sousa and followers", "Marcelo de Jesus Silva and his death squad", "Shankill Butchers",
    "Brabant killers", "Gang of Amazons", "Murder Incorporated", "Auto Shankar's Gang", "Mailoni Brothers",
    "Briley Brothers", "David Avendaño Ballina and his followers", "Philadelphia poison ring"
]

couples = [
    "Michael Bear Carson and Suzan Carson", "Paul Bernardo and Karla Homolka", "Raymond Fernandez and Martha Beck",
    "David and Catherine Birnie", "James Gregory Marlow and Cynthia Coffman", "Rudolfo Infante and Anna Villeda",
    "Gerald and Charlene Gallego", "Juan Carlos Hernández and Patricia Martínez", "Fred West and Rosemary West",
    "Adolfo Constanzo and Sara Aldrete", "Ray and Faye Copeland", "Ian Brady and Myra Hindley",
    "Futoshi Matsunaga and Junko Ogata", "Long Zhimin and Yan Shuxia", "Abboud and Khajawa"
]

male_groups = [
    "Joseph and Michael Kallinger", "James Paster and Stephen McCoy", "John Duffy and David Mulcahy",
    "Loren Herzog and Wesley Shermantine", "Lawrence Bittaker and Roy Norris",
    "Artyom Alexandrovich Anoufriev and Nikita Vakhtangovich Lytkin", "David Alan Gore and Fred Waterfield",
    "Hermann Duft and Hans Wilhelm Bassenauer", "Kiss brothers and Zsolt István Pető", "Gert van Rooyen and Joey Haarhof",
    "Johannes van Rooyen and Dumisani Makhubela", "Fa Ziying and Lao Rongzhi", "Christopher Worrell and James Miller",
    "Dale Hausner and Samuel Dieteman", "Edgar Álvarez Cruz and Francisco Granados", "Song Jinghua and Yan Jinguang",
    "Yevgeny Nagorny and Sergei Stavitsky", "Wolfgang Abel and Marco Furlan", "Polatbay Berdaliyev and Abduseit Ormanov",
    "Shen Changyin and Shen Changpin", "Leonard Lake and Charles Ng", "John Justin Bunting, Robert Joe Wagner and James Spyridon Vlassakis",
    "José Miculax Bux and Mariano Macú Miculax", "Vladyslav Volkovic and Volodymyr Kondratenko",
    "John Allen Muhammad and Lee Boyd Malvo", "Wang Zongfang and Wang Zongwei", "Viktor Sayenko and Igor Suprunyuk",
    "Dean Corll, David Owen Brooks and Elmer Wayne Henley", "Bian Kuang, Fu Xinyuan and Luo Lianshun",
    "Hassan Orangi and Abbas Ali Zarifian", "Peng Miaoji, Ding Yunjia and Su Xiaoping"
]

unidentified = [
    "Monster of the Mangones", "Cape Town Prostitute Killer", "El Psicópata",
    "Atlanta Ripper", "Cleveland Torso Murderer", "Rainbow Maniac", "Paraquat murders",
    "Long Island serial killer", "New Bedford Highway", "Edgecombe County Serial Killer",
    "Axeman of New Orleans", "Forest City Killer", "Łódź Gay Murderer", "The Doodler", "Bible John","Monster of Florence"
]

# FUNCTION TO APPLY:

def classify_killer(name):
    if name in female_killers:
        return 'Female'
    elif name in gangs:
        return 'Gang'
    elif name in couples:
        return 'Couple'
    elif name in male_groups:
        return 'Male Group'
    elif name in unidentified:
        return 'Unidentified'
    else:
        return 'Male'

# APPLYING THE FUNCTION TO THE DATA FRAME

victims['Killer Type'] =  victims['Name'].apply(classify_killer)

# %%
#CRIATING POSSIBLE NON PROVEN VICTIMS, WHICH IS THE DIFFERENCE FROM POSSIBLE VICTMS AND PROVEN

victims['Unproven Possible Victims'] = victims['Possible victims'] - victims['Proven victims']

# %%
# RENAMING POSSIBLE VICTIMS TO 'Total victims (Unproven + Proven)' TO BE MORE DISCRITIVE

victims.rename(columns={'Possible victims': 'Total victims (Unproven + Proven)'}, inplace=True)

# %%
# CREATING COLUNN 'YEARS ACTIVE' TO UNDERSTAND THE PERIOD OF ACTIVITY FROM KILLERS/ CRIMES

victims['Years Active'] = victims['End year'] - victims['Start year']

# %%
# REORDERING COLUMNS BY SIMILARITY

toreorder = ['Name',
             'Killer Type', 
             'Country', 
             'Country sorted' , 
             'Continent',
             'Start year', 
             'End year', 
             'Median Year', 
             'Years Active',
             'Decade', 
             'Total victims (Unproven + Proven)',
             'Unproven Possible Victims',
             'Proven victims',
             'Notes']

victims = victims[toreorder]

# %%
# ALL COLUMNS NAMES TO TITLE

victims.columns = victims.columns.str.title()

# %%
# CONFIRMING ALL CHANGES

victims.head(2)
# Out:
#             Name Killer Type                       Country  \
# 0  Luis Garavito        Male  Colombia, Ecuador, Venezuela
# 1    Pedro López        Male       Colombia, Peru, Ecuador
#
#        Country Sorted      Continent  Start Year  End Year  Median Year  \
# 0  Multiple Countries  South America        1992      1999         1995
# 1  Multiple Countries  South America        1969      1980         1974
#
#    Years Active Decade  Total Victims (Unproven + Proven)  \
# 0             7  1990s                                247
# 1            11  1970s                                300
#
#    Unproven Possible Victims  Proven Victims  \
# 0                         54             193
# 1                        190             110
#
#                                                Notes
# 0  Child-murderer, torture-killer, and rapist kno...
# 1  Child-murderer and rapist, known as "The Monst...

# %%
victims.to_csv('../Clean Files/Victims/1V-serial_killers_by_victims.csv', index=False)

# %% [markdown]
# ### CREATING TOP 15 KILLERS FILE

# %%
top15 = pd.read_csv('../Clean Files/Victims/1V-serial_killers_by_victims.csv')

# %%
# SORTING THE TOP 15 BASED ON 'POSSIBLE VICTIMS' , THIS COLUMN HAS BEEN IDENTIFYIED AS A POSSIBLE TOTAL VICTIMS LATER

top15 = top15.sort_values(by='Total Victims (Unproven + Proven)', ascending=False,).head(15).copy()

# %%
# CREATION OF DICTIONARY INCLUDING URL WITH KILLER PHOTO TO INCLUDE AS A COLUMN LATER

imagenes = {
    'Murder Incorporated': 'https://www.legendsofamerica.com/wp-content/uploads/2017/08/Murderinc.jpg',
    'The Skin Hunters': 'https://static.wikia.nocookie.net/skdb/images/2/2c/Andrzej_Nowocie%C5%84.jpg/revision/latest?cb=20230707162353',
    'Charles Cullen': 'https://media-cldnry.s-nbcnews.com/image/upload/t_fit-1500w,f_auto,q_auto:best/msnbc/Components/Photos/060319/060319_cullen_vsml_8a.jpg',
    'Amelia Sach and Annie Walters': 'https://pm1.aminoapps.com/6044/e102b3c5568cd78a3fb4e16d3d4d4f032f526a8b_00.jpg',
    'Pedro López': 'https://s3.amazonaws.com/arc-wordpress-client-uploads/infobae-wp/wp-content/uploads/2018/11/14100939/Pedro-Alonso-Lopez-el-Monstruo-de-los-Andes-3.jpg',
    'Angel Makers of Nagyrév': 'https://www.economist.com/cdn-cgi/image/width=1424,quality=80,format=auto/content-assets/images/20230318_CUP001.jpg',
    'Niels Högel': 'https://www.lavanguardia.com/files/content_image_mobile_filter/uploads/2022/04/21/6261a4bb37515.jpeg',
    'Abul Djabar': 'https://alpha-assets.tadevel-cdn.com/663d766925bc4c6ee7e00f81/720.webp',
    'Frans Hooijmaijers': 'https://thumbor.pijper.io/5EwhMNHH-OViNv253yb-ej8DMuY=/728x0/https%3A%2F%2Fcdn.pijper.io%2F2024%2F11%2Fq6DZBqjmCkIjDH1731685697.png',
    'Harold Shipman': 'https://m.media-amazon.com/images/S/pv-target-images/43d413170f9c3edaac3eceefaedc067b210f7cd44f5566140bceeb13ac977637.jpg',
    'Luis Garavito': 'https://upload.wikimedia.org/wikipedia/commons/7/7b/Luis_Alfredo_Garavito_Cubillos.jpg',
    'Kermit Gosnell': 'https://media.philly.com/images/20140213_dn_0n0wr3al.jpg',
    'Daniel Camargo Barbosa': 'https://upload.wikimedia.org/wikipedia/commons/e/ef/Daniel_Camargo_Barbosa_1958_Mugshot.png',
    'Mariam Soulakiotis': 'https://images.findagrave.com/photos/2024/251/245406222_a2b9c415-c479-410f-afd9-71f5b42a883a.jpeg',
    'Richard Kuklinski': 'https://swashvillage.org/storage/img/images/richard-the-iceman-kuklinski-biography_2.jpg'
}

# %%
# CREATING COLUMN WITH PHOTO OF THE KILLERS

top15['Image'] = top15['Name'].map(imagenes)

# %%
top15.head()
# Out:
#                               Name Killer Type                  Country  \
# 675            Murder Incorporated        Gang            United States
# 737               The Skin Hunters        Gang                   Poland
# 631                 Charles Cullen        Male            United States
# 756  Amelia Sach and Annie Walters      Female           United Kingdom
# 1                      Pedro López        Male  Colombia, Peru, Ecuador
#
#          Country Sorted      Continent  Start Year  End Year  Median Year  \
# 675       United States  North America      1920.0       NaN          NaN
# 737              Poland         Europe         NaN    2002.0          NaN
# 631       United States  North America      1988.0    2003.0       1995.0
# 756      United Kingdom         Europe      1900.0    1903.0       1901.0
# 1    Multiple Countries  South America      1969.0    1980.0       1974.0
#
#      Years Active Decade  Total Victims (Unproven + Proven)  \
# 675           NaN  <NA>s                               1000
# 737           NaN  <NA>s                                620
# 631          15.0  1990s                                400
# 756           3.0  1900s                                300
# 1            11.0  1970s                                300
#
#      Unproven Possible Victims  Proven Victims  \
# 675                        600             400
# 737                        615               5
# 631                        371              29
# 756                        299               1
# 1                          190             110
#
#                                                  Notes  \
# 675  Murder Incorporated or Murder Inc. for short w...
# 737  Hospital crew that killed patients in order to...
# 631  Nurse in New Jersey and Pennsylvania who murde...
# 756  Sach and Walters, known as the "Finchley baby ...
# 1    Child-murderer and rapist, known as "The Monst...
#
#                                                  Image
# 675  https://www.legendsofamerica.com/wp-content/up...
# 737  https://static.wikia.nocookie.net/skdb/images/...
# 631  https://media-cldnry.s-nbcnews.com/image/uploa...
# 756  https://pm1.aminoapps.com/6044/e102b3c5568cd78...
# 1    https://s3.amazonaws.com/arc-wordpress-client-...

# %%
# OBSERVED SOME OF THE COLUMNS WENT BACK TO FLOAT, THEN HAVING THEM AS INT

top15[['Start Year', 'End Year', 'Median Year', 'Years Active']] = top15[['Start Year', 'End Year', 'Median Year', 'Years Active']].astype('Int64')

# %%
#CONFIRMING DATA FORMAT

top15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, 675 to 490
# Data columns (total 15 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Name                               15 non-null     object
#  1   Killer Type                        15 non-null     object
#  2   Country                            15 non-null     object
#  3   Country Sorted                     15 non-null     object
#  4   Continent                          15 non-null     object
#  5   Start Year                         12 non-null     Int64
#  6   End Year                           14 non-null     Int64
#  7   Median Year                        11 non-null     Int64
#  8   Years Active                       11 non-null     Int64
#  9   Decade                             15 non-null     object
#  10  Total Victims (Unproven + Proven)  15 non-null     int64
#  11  Unproven Possible Victims          15 non-null     int64
#  12  Proven Victims                     15 non-null     int64
#  13  Notes                              14 non-null     object
#  14  Image                              15 non-null     object
# dtypes: Int64(4), int64(3), object(8)
# memory usage: 1.9+ KB

# %%
top15.to_csv('../Clean Files/Victims/top15_killers_by_victims.csv', index=False)
